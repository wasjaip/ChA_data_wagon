# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Догружаем-Февраль-и-Март" data-toc-modified-id="Догружаем-Февраль-и-Март-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Догружаем Февраль и Март</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Выделение-признаков" data-toc-modified-id="Выделение-признаков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выделение признаков</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обучение</a></span></li></ul></li><li><span><a href="#генетический-алгоритм-для-сборки-моделей-(день)" data-toc-modified-id="генетический-алгоритм-для-сборки-моделей-(день)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>генетический алгоритм для сборки моделей (день)</a></span></li><li><span><a href="#генетический-алгоритм-для-сборки-моделей-(месяц)" data-toc-modified-id="генетический-алгоритм-для-сборки-моделей-(месяц)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>генетический алгоритм для сборки моделей (месяц)</a></span><ul class="toc-item"><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Создаем-выходной-файл-и-тестируем-скорингом" data-toc-modified-id="Создаем-выходной-файл-и-тестируем-скорингом-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Создаем выходной файл и тестируем скорингом</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Отчет по Проекту Предсказания Ремонта Вагонов
#
# ## Введение
# От имени нашей команды, мы рады представить результаты нашего последнего проекта по предсказанию решений по отправке вагонов на ремонт. Наш подход основывался на гипотезе, что принятие таких решений не требует анализа большого числа признаков, что помогло избежать переобучения модели.
#
# ## Методология
# - **Гипотеза:** Принятие решений не требует анализа большого числа признаков.
# - **Используемые признаки:** `ost_prob` и `mean_run`.
# - **Результат:** F1-скор 0.5047 на тестовых данных.
#
# ## Вызовы и Решения
# - **Проблема:** Модель недооценивает объем вагонов, отправляемых на ремонт в следующем месяце.
# - **Решение:** Корректировка порогового значения для определения необходимости ремонта вагона.
# - **Дополнительные меры:** Исследование различных подходов к обработке данных и настройке модели, включая эксперименты с различными комбинациями признаков и методами их обработки.
#
# ## Заключение
# Используя всего два признака (ost_prob и mean_run), мы достигли впечатляющего результата с F1-скором 0.5047 на тестовых данных. Это подтверждает, что простота модели иногда может быть ключом к её эффективности.
#
# Однако, мы также столкнулись с некоторыми вызовами. Например, модель, обученная на данных одного месяца, склонна недооценивать объем вагонов, отправляемых на ремонт в следующем месяце. Мы предположили, что это может быть связано с изменениями в политике ремонта вагонов. Решение этой проблемы заключалось в корректировке порогового значения для определения необходимости ремонта вагона, что позволило улучшить точность предсказаний.
#
# Также, важной частью нашей работы стало исследование различных подходов к обработке данных и настройке модели. Мы провели серию экспериментов с различными комбинациями признаков и методами их обработки, что позволило нам глубже понять динамику и особенности наших данных. Это, в свою очередь, привело к более эффективному и точному предсказанию.
#
# В заключение, наш проект подчеркнул значимость гибкости и адаптивности в машинном обучении, особенно при работе с данными, подверженными изменениям во времени. Мы убеждены, что эти выводы будут полезны не только для нашего текущего проекта, но и для будущих исследований в этой области.
#
#
# ---
#
# > *Команда [DS-60]*

# %%
# Попытка импортировать основные библиотеки для работы с данными
try:
    import pandas as pd
    import numpy as np
except ImportError as e:
    print(f"Не удалось импортировать библиотеки Pandas или NumPy: {e}")

# Попытка импортировать библиотеки машинного обучения
try:
    from catboost import CatBoostClassifier
    from lightgbm import LGBMClassifier
    from xgboost import XGBClassifier
    # import catboost
except ImportError as e:
    print(f"Не удалось импортировать библиотеки машинного обучения (CatBoost, LightGBM, XGBoost): {e}")

# Попытка импортировать инструменты для настройки модели и предобработки данных
try:
    from sklearn.model_selection import train_test_split, RandomizedSearchCV
    from sklearn.preprocessing import LabelEncoder
except ImportError as e:
    print(f"Не удалось импортировать инструменты sklearn для настройки модели и предобработки данных: {e}")

# Попытка импортировать метрики для оценки качества модели
try:
    from sklearn.metrics import f1_score, precision_recall_curve
except ImportError as e:
    print(f"Не удалось импортировать метрики из sklearn: {e}")

# Попытка импортировать инструменты для генетического алгоритма
try:
    import random
    from deap import base, creator, tools, algorithms
except ImportError as e:
    print(f"Не удалось импортировать библиотеки для генетического алгоритма (DEAP): {e}")

# Попытка импортировать локальные скрипты или дополнительные функции
try:
    from metrics_f1 import calc_f1_score
except ImportError as e:
    print(f"Не удалось импортировать локальные скрипты или дополнительные функции: {e}")

# %% [markdown]
# ## Загрузка данных

# %%
path_train = r"./"

# %%
# данные по дислокации
dislok = pd.read_parquet(path_train + '/dislok_wagons.parquet').convert_dtypes()
# данные по текущим ремонтам
pr_rem = pd.read_parquet(path_train + '/pr_rems.parquet').convert_dtypes()
# список вагонов с остаточным пробегом на момент прогноза
wag_prob = pd.read_parquet(path_train + '/wagons_probeg_ownersip.parquet').convert_dtypes()
 # параметры вагона
wag_param = pd.read_parquet(path_train + '/wag_params.parquet').convert_dtypes()
# таргет по прогноза выбытия вагонов в ПР на месяц и на 10 дней
target = pd.read_csv(path_train +'/target/y_train.csv').convert_dtypes()
 # текущие ремонты вагонов
tr_rem = pd.read_parquet(path_train + '/tr_rems.parquet').convert_dtypes()

# %% [markdown]
# ### Догружаем Февраль и Март

# %%
# список вагонов с остаточным пробегом на момент прогноза за февраль
wag_prob_feb = pd.read_parquet(path_train + './test/wagons_probeg_ownersip.parquet').convert_dtypes()
# таргет по прогноза выбытия вагонов в ПР на месяц и на 10 дней  за февраль
target_feb = pd.read_csv(path_train +'./test/target/y_test.csv').convert_dtypes()
# таргет по прогноза выбытия вагонов в ПР на месяц и на 10 дней  за март (без реальных предсказаний)
target_march = pd.read_csv(path_train +'./target/y_predict_submit_example.csv').convert_dtypes()

# %%
# Присоединяем данные за февраль
wag_prob = pd.concat([wag_prob_feb, wag_prob])
target = pd.concat([target_feb, target])
# Присоединяем данные за март
target = pd.concat([target_march, target])
# Переносим последний день февраля на 1 марта
wag_prob.loc[wag_prob.repdate=='2023-02-28', 'repdate'] = '2023-03-01'

# %%
wag_param = wag_param.drop_duplicates(subset='wagnum', keep='last')# у вагонов могут меняться параметры, поэтмоу номер дублируется. В данной модели это фактор не учитывается

# %%
target.month = pd.to_datetime(target.month)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Выделение признаков

# %%
def wag_prob_transform(wag_prob, month_to_cut):
    # Параметры:
    # month_to_cut - по какой месяц обрезать данные

    # оставим только данные по остаточному пробегу для каждого номерав вагона
    wag_prob_new = wag_prob[(wag_prob.repdate == month_to_cut) | (wag_prob.repdate == wag_prob.repdate.min())]

    # оценим среднесуточный пробег из данных по пробегу вагона, на тот случай, если данных по нормативу нет
    wag_prob_ =wag_prob_new.groupby('wagnum', as_index = False).agg({'repdate':['max', 'min'] , 'ost_prob': ['max','min']},)#.droplevel(1)
    wag_prob_.columns = [head+'_' + name
                         if head!='wagnum'
                         else head
                         for head, name in wag_prob_.columns ]

    wag_prob_['diff_days'] = wag_prob_.repdate_max - wag_prob_.repdate_min
    wag_prob_['mean_run'] = (wag_prob_.ost_prob_max - wag_prob_.ost_prob_min )/ wag_prob_.diff_days.dt.days
    wag_prob_new = wag_prob_new[wag_prob_new.repdate == wag_prob_new.repdate.max()][['wagnum','ost_prob']]
    wag_prob_new = wag_prob_new.merge(wag_prob_[['wagnum','mean_run']])

    return wag_prob_new

# %%
# Возвращает среднюю скорость только за один месяц до указанного, а не среднюю скорость за все время
def month_mean_run(wag_prob, next_month):
    # Параметры:
    # next_month - месяц следующий за тем, для которого считать скорость

    prev_month = next_month - pd.DateOffset(months=1)
    # оставим только данные по остаточному пробегу для каждого номерав вагона
    wag_prob_new = wag_prob[(wag_prob.repdate == next_month) | (wag_prob.repdate == prev_month)]

    # оценим среднесуточный пробег из данных по пробегу вагона, на тот случай, если данных по нормативу нет
    wag_prob_ =wag_prob_new.groupby('wagnum', as_index = False).agg({'repdate':['max', 'min'] , 'ost_prob': ['max','min']},)#.droplevel(1)
    wag_prob_.columns = [head+'_' + name
                         if head!='wagnum'
                         else head
                         for head, name in wag_prob_.columns ]

    wag_prob_['diff_days'] = wag_prob_.repdate_max - wag_prob_.repdate_min
    wag_prob_['mean_run'] = (wag_prob_.ost_prob_max - wag_prob_.ost_prob_min )/ wag_prob_.diff_days.dt.days
    wag_prob_new = wag_prob_new[wag_prob_new.repdate == wag_prob_new.repdate.max()][['wagnum','ost_prob']]
    wag_prob_new = wag_prob_new.merge(wag_prob_[['wagnum','mean_run']])
    wag_prob_new = wag_prob_new.fillna(0)

    return wag_prob_new

# %%
# Возвращает фичи и целевые признаки для обучения или для валидации.
# С учетом до какого месяца обрезать данные
def get_features(wag_prob, target, month_to_cut):
    # Параметры:
    # month_to_cut - по какой месяц обрезать данные

    # Данные с целевым признаком для обучения на конкретный месяц month_to_learn.
    # Ремонт в этом месяце target_month и отдельно ремонт в первые 10 дней этого месяца target_day
    target_learn = target[target.month == month_to_cut][['wagnum','target_month','target_day']]

    # Обрезаем данные по пробегу вагонов до месяца на который будем предсказывать.
    # И делаем новые признаки связанные с пробегом
    wag_prob_learn = wag_prob_transform(wag_prob, month_to_cut)

    '''
    #Месяц начала данных
    next_month = pd.to_datetime('2022-09-01')

    # Добавим средние скорости за один месяц
    for i in range(1, 4):
        next_month = start_month + pd.DateOffset(months=i)
        speed_col_name = f'mean_run_{i}'
        wag_prob_learn[speed_col_name] = month_mean_run(wag_prob, next_month)[['mean_run']]
        print(next_month)
    '''

    # Сводим в один датасет по каждому вагону его признаки и целевую переменную. (Целевая бует или нет отправлен на ремонт)
    data = target_learn.merge(wag_prob_learn, on='wagnum', how='left')
    data = data.fillna(0)

    #Выделим целевые признаки
    y_month = data['target_month']
    y_day = data['target_day']

    # Выделим признаки
    X = data.drop(['target_month', 'target_day'], axis=1)

    return y_month, y_day, X

# %% [markdown]
# ### Обучение

# %%
# Месяц до которого которого будем обрезать данные и обучаться предсказывать ремонт в этом месяце.
#month_to_learn = pd.to_datetime('2023-01-01')
month_to_learn = pd.to_datetime('2023-02-01')
y_month, y_day, X = get_features(wag_prob, target, month_to_learn)

# %% [markdown]
# {'n_estimators': 1000, 'learning_rate': 0.01, 'l2_leaf_reg': 9, 'depth': 4}
#
# {'n_estimators': 50,'learning_rate': 0.10666666666666666,'l2_leaf_reg': 1,'depth': 8}

# %%
from sklearn.model_selection import RandomizedSearchCV
# Инициализируем модели
month_model = CatBoostClassifier(verbose=100)
day_model = CatBoostClassifier(verbose=100)

# Задаем параметры для поиска
param_dist_1 = {
    'depth': [4, 6],
    'learning_rate': np.linspace(0.01, 0.3, 10),
    'n_estimators': [500, 1000],
    'l2_leaf_reg': [7, 9]
}
param_dist_2 = {
    'depth': [8, 10],
    'learning_rate': np.linspace(0.01, 0.3, 10),
    'n_estimators': [50],
    'l2_leaf_reg': [1]
}
# Настройка RandomizedSearchCV
month_model = RandomizedSearchCV(month_model, param_distributions=param_dist_1, n_iter=50, scoring='accuracy', cv=3)
day_model = RandomizedSearchCV(day_model, param_distributions=param_dist_2, n_iter=50, scoring='accuracy', cv=3)

# Обучение моделей
month_model.fit(X, y_month)
day_model.fit(X, y_day)
# Out:
# 0:	learn: 0.5243467	total: 10ms	remaining: 9.99s
# 100:	learn: 0.0885944	total: 1.07s	remaining: 9.52s
# 200:	learn: 0.0844064	total: 2.16s	remaining: 8.59s
# 300:	learn: 0.0814544	total: 3.25s	remaining: 7.55s
# 400:	learn: 0.0790285	total: 4.43s	remaining: 6.62s
# 500:	learn: 0.0769285	total: 5.49s	remaining: 5.47s
# 600:	learn: 0.0750158	total: 6.55s	remaining: 4.34s
# 700:	learn: 0.0734630	total: 7.59s	remaining: 3.24s
# 800:	learn: 0.0718462	total: 8.66s	remaining: 2.15s
# 900:	learn: 0.0703453	total: 9.71s	remaining: 1.07s
# 999:	learn: 0.0690327	total: 10.8s	remaining: 0us
# 0:	learn: 0.5480782	total: 11ms	remaining: 11s
# 100:	learn: 0.0822846	total: 1.11s	remaining: 9.88s
# 200:	learn: 0.0782982	total: 2.17s	remaining: 8.62s
# 300:	learn: 0.0750352	total: 3.25s	remaining: 7.54s
# 400:	learn: 0.0723532	total: 4.33s	remaining: 6.46s
# 500:	learn: 0.0703264	total: 5.4s	remaining: 5.38s
# 600:	learn: 0.0684734	total: 6.56s	remaining: 4.36s
# 700:	learn: 0.0668711	total: 7.72s	remaining: 3.29s
# 800:	learn: 0.0654326	total: 8.8s	remaining: 2.19s
# 900:	learn: 0.0641406	total: 9.85s	remaining: 1.08s
# 999:	learn: 0.0629960	total: 11s	remaining: 0us
# 0:	learn: 0.5018631	total: 11.3ms	remaining: 11.3s
# 100:	learn: 0.0840787	total: 1.14s	remaining: 10.1s
# 200:	learn: 0.0805449	total: 2.24s	remaining: 8.9s
# 300:	learn: 0.0782401	total: 3.36s	remaining: 7.81s
# 400:	learn: 0.0762899	total: 4.46s	remaining: 6.66s
# 500:	learn: 0.0744351	total: 5.57s	remaining: 5.55s
# 600:	learn: 0.0725427	total: 6.64s	remaining: 4.41s
# 700:	learn: 0.0709281	total: 7.71s	remaining: 3.29s
# 800:	learn: 0.0693067	total: 8.89s	remaining: 2.21s
# 900:	learn: 0.0678325	total: 10s	remaining: 1.1s
# 999:	learn: 0.0664759	total: 11.1s	remaining: 0us
# 0:	learn: 0.4112992	total: 13.6ms	remaining: 6.79s
# 100:	learn: 0.0804681	total: 1.31s	remaining: 5.18s
# 200:	learn: 0.0718750	total: 2.61s	remaining: 3.88s
# 300:	learn: 0.0659619	total: 3.88s	remaining: 2.56s
# 400:	learn: 0.0609424	total: 5.18s	remaining: 1.28s
# 499:	learn: 0.0571149	total: 6.37s	remaining: 0us
# 0:	learn: 0.4480714	total: 13ms	remaining: 6.51s
# 100:	learn: 0.0735233	total: 1.22s	remaining: 4.8s
# 200:	learn: 0.0650244	total: 2.42s	remaining: 3.59s
# 300:	learn: 0.0591413	total: 3.61s	remaining: 2.39s
# 400:	learn: 0.0545876	total: 4.81s	remaining: 1.19s
# 499:	learn: 0.0508748	total: 5.99s	remaining: 0us
# 0:	learn: 0.3880606	total: 12.3ms	remaining: 6.15s
# 100:	learn: 0.0775021	total: 1.2s	remaining: 4.75s
# 200:	learn: 0.0694347	total: 2.4s	remaining: 3.56s
# 300:	learn: 0.0637377	total: 3.68s	remaining: 2.43s
# 400:	learn: 0.0589926	total: 5s	remaining: 1.23s
# 499:	learn: 0.0552615	total: 6.29s	remaining: 0us
# 0:	learn: 0.4643531	total: 12.3ms	remaining: 6.13s
# 100:	learn: 0.0864038	total: 1.18s	remaining: 4.66s
# 200:	learn: 0.0814713	total: 2.36s	remaining: 3.51s
# 300:	learn: 0.0779477	total: 3.54s	remaining: 2.34s
# 400:	learn: 0.0754493	total: 4.69s	remaining: 1.16s
# 499:	learn: 0.0732094	total: 5.83s	remaining: 0us
# 0:	learn: 0.4944480	total: 12.4ms	remaining: 6.2s
# 100:	learn: 0.0806409	total: 1.18s	remaining: 4.65s
# 200:	learn: 0.0754043	total: 2.33s	remaining: 3.46s
# 300:	learn: 0.0719029	total: 3.48s	remaining: 2.3s
# 400:	learn: 0.0689676	total: 4.63s	remaining: 1.14s
# 499:	learn: 0.0667215	total: 5.77s	remaining: 0us
# 0:	learn: 0.4362492	total: 12ms	remaining: 6s
# 100:	learn: 0.0828844	total: 1.16s	remaining: 4.6s
# 200:	learn: 0.0788372	total: 2.31s	remaining: 3.44s
# 300:	learn: 0.0758411	total: 3.45s	remaining: 2.28s
# 400:	learn: 0.0731778	total: 4.6s	remaining: 1.14s
# 499:	learn: 0.0707624	total: 5.73s	remaining: 0us
# 0:	learn: 0.3656865	total: 12.7ms	remaining: 6.32s
# 100:	learn: 0.0837104	total: 1.17s	remaining: 4.64s
# 200:	learn: 0.0775849	total: 2.33s	remaining: 3.46s
# 300:	learn: 0.0736781	total: 3.48s	remaining: 2.3s
# 400:	learn: 0.0701218	total: 4.63s	remaining: 1.14s
# 499:	learn: 0.0669949	total: 5.78s	remaining: 0us
# 0:	learn: 0.4025666	total: 12.7ms	remaining: 6.35s
# 100:	learn: 0.0771891	total: 1.13s	remaining: 4.48s
# 200:	learn: 0.0711112	total: 2.28s	remaining: 3.4s
# 300:	learn: 0.0668439	total: 3.43s	remaining: 2.27s
# 400:	learn: 0.0637546	total: 4.56s	remaining: 1.13s
# 499:	learn: 0.0611091	total: 5.68s	remaining: 0us
# 0:	learn: 0.3322726	total: 12.3ms	remaining: 6.15s
# 100:	learn: 0.0799535	total: 1.21s	remaining: 4.77s
# 200:	learn: 0.0750277	total: 2.38s	remaining: 3.54s
# 300:	learn: 0.0708841	total: 3.54s	remaining: 2.34s
# 400:	learn: 0.0673572	total: 4.7s	remaining: 1.16s
# 499:	learn: 0.0644670	total: 5.85s	remaining: 0us
# 0:	learn: 0.2613166	total: 12.4ms	remaining: 6.17s
# 100:	learn: 0.0796731	total: 1.17s	remaining: 4.63s
# 200:	learn: 0.0720376	total: 2.34s	remaining: 3.48s
# 300:	learn: 0.0663139	total: 3.49s	remaining: 2.31s
# 400:	learn: 0.0614474	total: 4.64s	remaining: 1.15s
# 499:	learn: 0.0576296	total: 5.8s	remaining: 0us
# 0:	learn: 0.2974820	total: 12.8ms	remaining: 6.4s
# 100:	learn: 0.0730880	total: 1.2s	remaining: 4.75s
# 200:	learn: 0.0658356	total: 2.41s	remaining: 3.58s
# 300:	learn: 0.0604110	total: 3.59s	remaining: 2.37s
# 400:	learn: 0.0565411	total: 4.75s	remaining: 1.17s
# 499:	learn: 0.0527716	total: 5.9s	remaining: 0us
# 0:	learn: 0.2285158	total: 12.8ms	remaining: 6.38s
# 100:	learn: 0.0765771	total: 1.18s	remaining: 4.66s
# 200:	learn: 0.0700338	total: 2.34s	remaining: 3.48s
# 300:	learn: 0.0642508	total: 3.51s	remaining: 2.32s
# 400:	learn: 0.0598203	total: 4.66s	remaining: 1.15s
# 499:	learn: 0.0562090	total: 5.82s	remaining: 0us
# 0:	learn: 0.6677680	total: 12.8ms	remaining: 12.7s
# 100:	learn: 0.1274483	total: 1.18s	remaining: 10.5s
# 200:	learn: 0.1008065	total: 2.35s	remaining: 9.36s
# 300:	learn: 0.0941612	total: 3.51s	remaining: 8.14s
# 400:	learn: 0.0918188	total: 4.67s	remaining: 6.97s
# 500:	learn: 0.0904664	total: 5.83s	remaining: 5.8s
# 600:	learn: 0.0894787	total: 6.97s	remaining: 4.63s
# 700:	learn: 0.0886663	total: 8.11s	remaining: 3.46s
# 800:	learn: 0.0881085	total: 9.25s	remaining: 2.3s
# 900:	learn: 0.0875400	total: 10.4s	remaining: 1.14s
# 999:	learn: 0.0869625	total: 11.5s	remaining: 0us
# 0:	learn: 0.6717347	total: 13.1ms	remaining: 13.1s
# 100:	learn: 0.1182744	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0939751	total: 2.39s	remaining: 9.49s
# 300:	learn: 0.0880174	total: 3.57s	remaining: 8.3s
# 400:	learn: 0.0856168	total: 4.76s	remaining: 7.11s
# 500:	learn: 0.0841224	total: 5.93s	remaining: 5.91s
# 600:	learn: 0.0831954	total: 7.13s	remaining: 4.73s
# 700:	learn: 0.0824346	total: 8.31s	remaining: 3.54s
# 800:	learn: 0.0817948	total: 9.46s	remaining: 2.35s
# 900:	learn: 0.0812326	total: 10.6s	remaining: 1.17s
# 999:	learn: 0.0806815	total: 11.8s	remaining: 0us
# 0:	learn: 0.6637606	total: 12.9ms	remaining: 12.8s
# 100:	learn: 0.1189335	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0938604	total: 2.42s	remaining: 9.61s
# 300:	learn: 0.0888985	total: 3.63s	remaining: 8.43s
# 400:	learn: 0.0870100	total: 4.86s	remaining: 7.26s
# 500:	learn: 0.0859015	total: 6.09s	remaining: 6.06s
# 600:	learn: 0.0850294	total: 7.27s	remaining: 4.83s
# 700:	learn: 0.0843423	total: 8.48s	remaining: 3.62s
# 800:	learn: 0.0838112	total: 9.68s	remaining: 2.4s
# 900:	learn: 0.0832322	total: 10.9s	remaining: 1.19s
# 999:	learn: 0.0827504	total: 12.1s	remaining: 0us
# 0:	learn: 0.3630495	total: 16.7ms	remaining: 8.34s
# 100:	learn: 0.0766533	total: 1.42s	remaining: 5.59s
# 200:	learn: 0.0669282	total: 2.85s	remaining: 4.24s
# 300:	learn: 0.0601429	total: 4.25s	remaining: 2.81s
# 400:	learn: 0.0551662	total: 5.65s	remaining: 1.4s
# 499:	learn: 0.0504067	total: 7.07s	remaining: 0us
# 0:	learn: 0.4032536	total: 15.2ms	remaining: 7.56s
# 100:	learn: 0.0708117	total: 1.42s	remaining: 5.61s
# 200:	learn: 0.0607251	total: 2.82s	remaining: 4.19s
# 300:	learn: 0.0543849	total: 4.24s	remaining: 2.8s
# 400:	learn: 0.0494240	total: 5.68s	remaining: 1.4s
# 499:	learn: 0.0451107	total: 7.1s	remaining: 0us
# 0:	learn: 0.3369547	total: 15.4ms	remaining: 7.68s
# 100:	learn: 0.0744159	total: 1.45s	remaining: 5.74s
# 200:	learn: 0.0657086	total: 2.85s	remaining: 4.24s
# 300:	learn: 0.0591819	total: 4.28s	remaining: 2.83s
# 400:	learn: 0.0533045	total: 5.71s	remaining: 1.41s
# 499:	learn: 0.0489569	total: 7.11s	remaining: 0us
# 0:	learn: 0.4090508	total: 15.1ms	remaining: 7.53s
# 100:	learn: 0.0790728	total: 1.41s	remaining: 5.58s
# 200:	learn: 0.0700018	total: 2.82s	remaining: 4.19s
# 300:	learn: 0.0640510	total: 4.23s	remaining: 2.79s
# 400:	learn: 0.0590173	total: 5.58s	remaining: 1.38s
# 499:	learn: 0.0547683	total: 6.93s	remaining: 0us
# 0:	learn: 0.4467426	total: 16.3ms	remaining: 8.14s
# 100:	learn: 0.0729005	total: 1.38s	remaining: 5.43s
# 200:	learn: 0.0640947	total: 2.73s	remaining: 4.07s
# 300:	learn: 0.0582446	total: 4.08s	remaining: 2.7s
# 400:	learn: 0.0538333	total: 5.43s	remaining: 1.34s
# 499:	learn: 0.0495202	total: 6.77s	remaining: 0us
# 0:	learn: 0.3845300	total: 14.6ms	remaining: 7.3s
# 100:	learn: 0.0771571	total: 1.37s	remaining: 5.41s
# 200:	learn: 0.0687174	total: 2.72s	remaining: 4.04s
# 300:	learn: 0.0626773	total: 4.05s	remaining: 2.68s
# 400:	learn: 0.0572929	total: 5.41s	remaining: 1.33s
# 499:	learn: 0.0532872	total: 6.73s	remaining: 0us
# 0:	learn: 0.3653945	total: 15.5ms	remaining: 7.73s
# 100:	learn: 0.0771066	total: 1.37s	remaining: 5.4s
# 200:	learn: 0.0683093	total: 2.72s	remaining: 4.05s
# 300:	learn: 0.0622240	total: 4.08s	remaining: 2.7s
# 400:	learn: 0.0570075	total: 5.46s	remaining: 1.35s
# 499:	learn: 0.0526566	total: 6.8s	remaining: 0us
# 0:	learn: 0.4046617	total: 15.4ms	remaining: 7.66s
# 100:	learn: 0.0709586	total: 1.38s	remaining: 5.44s
# 200:	learn: 0.0624039	total: 2.73s	remaining: 4.07s
# 300:	learn: 0.0560620	total: 4.08s	remaining: 2.69s
# 400:	learn: 0.0514486	total: 5.42s	remaining: 1.34s
# 499:	learn: 0.0475723	total: 6.76s	remaining: 0us
# 0:	learn: 0.3406042	total: 16.6ms	remaining: 8.28s
# 100:	learn: 0.0755075	total: 1.36s	remaining: 5.38s
# 200:	learn: 0.0664271	total: 2.72s	remaining: 4.05s
# 300:	learn: 0.0606092	total: 4.08s	remaining: 2.7s
# 400:	learn: 0.0558898	total: 5.46s	remaining: 1.35s
# 499:	learn: 0.0509623	total: 6.81s	remaining: 0us
# 0:	learn: 0.4619727	total: 15.9ms	remaining: 7.93s
# 100:	learn: 0.0818935	total: 1.42s	remaining: 5.59s
# 200:	learn: 0.0736768	total: 2.77s	remaining: 4.13s
# 300:	learn: 0.0680517	total: 4.15s	remaining: 2.74s
# 400:	learn: 0.0636753	total: 5.52s	remaining: 1.36s
# 499:	learn: 0.0598035	total: 6.85s	remaining: 0us
# 0:	learn: 0.4951147	total: 14.9ms	remaining: 7.45s
# 100:	learn: 0.0755419	total: 1.37s	remaining: 5.41s
# 200:	learn: 0.0675574	total: 2.72s	remaining: 4.04s
# 300:	learn: 0.0620308	total: 4.08s	remaining: 2.7s
# 400:	learn: 0.0578899	total: 5.42s	remaining: 1.34s
# 499:	learn: 0.0548302	total: 6.75s	remaining: 0us
# 0:	learn: 0.4403275	total: 14.9ms	remaining: 7.41s
# 100:	learn: 0.0791633	total: 1.39s	remaining: 5.48s
# 200:	learn: 0.0721306	total: 2.73s	remaining: 4.07s
# 300:	learn: 0.0671682	total: 4.08s	remaining: 2.7s
# 400:	learn: 0.0621067	total: 5.42s	remaining: 1.34s
# 499:	learn: 0.0583938	total: 6.76s	remaining: 0us
# 0:	learn: 0.2916368	total: 13.5ms	remaining: 13.5s
# 100:	learn: 0.0814692	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0739920	total: 2.38s	remaining: 9.48s
# 300:	learn: 0.0696564	total: 3.55s	remaining: 8.25s
# 400:	learn: 0.0654506	total: 4.73s	remaining: 7.06s
# 500:	learn: 0.0619146	total: 5.88s	remaining: 5.86s
# 600:	learn: 0.0586072	total: 7.04s	remaining: 4.68s
# 700:	learn: 0.0558521	total: 8.2s	remaining: 3.5s
# 800:	learn: 0.0536129	total: 9.37s	remaining: 2.33s
# 900:	learn: 0.0512382	total: 10.5s	remaining: 1.16s
# 999:	learn: 0.0492176	total: 11.7s	remaining: 0us
# 0:	learn: 0.3291966	total: 13.6ms	remaining: 13.6s
# 100:	learn: 0.0749751	total: 1.18s	remaining: 10.5s
# 200:	learn: 0.0676672	total: 2.35s	remaining: 9.32s
# 300:	learn: 0.0630008	total: 3.52s	remaining: 8.19s
# 400:	learn: 0.0592100	total: 4.7s	remaining: 7.03s
# 500:	learn: 0.0560905	total: 5.87s	remaining: 5.84s
# 600:	learn: 0.0534813	total: 7.02s	remaining: 4.66s
# 700:	learn: 0.0511455	total: 8.17s	remaining: 3.48s
# 800:	learn: 0.0488041	total: 9.32s	remaining: 2.32s
# 900:	learn: 0.0470120	total: 10.5s	remaining: 1.15s
# 999:	learn: 0.0454531	total: 11.6s	remaining: 0us
# 0:	learn: 0.2584680	total: 12.2ms	remaining: 12.2s
# 100:	learn: 0.0780808	total: 1.17s	remaining: 10.5s
# 200:	learn: 0.0720432	total: 2.34s	remaining: 9.29s
# 300:	learn: 0.0671015	total: 3.5s	remaining: 8.14s
# 400:	learn: 0.0629476	total: 4.66s	remaining: 6.96s
# 500:	learn: 0.0590990	total: 5.82s	remaining: 5.79s
# 600:	learn: 0.0560016	total: 6.97s	remaining: 4.63s
# 700:	learn: 0.0533511	total: 8.13s	remaining: 3.47s
# 800:	learn: 0.0511110	total: 9.28s	remaining: 2.31s
# 900:	learn: 0.0489399	total: 10.5s	remaining: 1.15s
# 999:	learn: 0.0468308	total: 11.6s	remaining: 0us
# 0:	learn: 0.4105346	total: 13.7ms	remaining: 13.7s
# 100:	learn: 0.0846290	total: 1.23s	remaining: 11s
# 200:	learn: 0.0788602	total: 2.44s	remaining: 9.7s
# 300:	learn: 0.0747103	total: 3.62s	remaining: 8.41s
# 400:	learn: 0.0711958	total: 4.8s	remaining: 7.17s
# 500:	learn: 0.0681549	total: 5.98s	remaining: 5.95s
# 600:	learn: 0.0657073	total: 7.16s	remaining: 4.75s
# 700:	learn: 0.0633421	total: 8.33s	remaining: 3.55s
# 800:	learn: 0.0609851	total: 9.49s	remaining: 2.36s
# 900:	learn: 0.0591511	total: 10.7s	remaining: 1.17s
# 999:	learn: 0.0572133	total: 11.8s	remaining: 0us
# 0:	learn: 0.4448374	total: 13ms	remaining: 13s
# 100:	learn: 0.0782920	total: 1.19s	remaining: 10.6s
# 200:	learn: 0.0727562	total: 2.36s	remaining: 9.37s
# 300:	learn: 0.0685732	total: 3.52s	remaining: 8.18s
# 400:	learn: 0.0653196	total: 4.69s	remaining: 7s
# 500:	learn: 0.0627671	total: 5.86s	remaining: 5.84s
# 600:	learn: 0.0606313	total: 7.01s	remaining: 4.66s
# 700:	learn: 0.0584932	total: 8.18s	remaining: 3.49s
# 800:	learn: 0.0564802	total: 9.34s	remaining: 2.32s
# 900:	learn: 0.0545035	total: 10.5s	remaining: 1.15s
# 999:	learn: 0.0527549	total: 11.6s	remaining: 0us
# 0:	learn: 0.3777536	total: 12.7ms	remaining: 12.7s
# 100:	learn: 0.0811915	total: 1.18s	remaining: 10.5s
# 200:	learn: 0.0764990	total: 2.35s	remaining: 9.34s
# 300:	learn: 0.0728191	total: 3.52s	remaining: 8.18s
# 400:	learn: 0.0693804	total: 4.68s	remaining: 6.99s
# 500:	learn: 0.0665816	total: 5.84s	remaining: 5.81s
# 600:	learn: 0.0637907	total: 6.98s	remaining: 4.64s
# 700:	learn: 0.0618752	total: 8.14s	remaining: 3.47s
# 800:	learn: 0.0599099	total: 9.28s	remaining: 2.31s
# 900:	learn: 0.0579884	total: 10.4s	remaining: 1.14s
# 999:	learn: 0.0562041	total: 11.6s	remaining: 0us
# 0:	learn: 0.3645513	total: 12.9ms	remaining: 6.46s
# 100:	learn: 0.0828689	total: 1.18s	remaining: 4.66s
# 200:	learn: 0.0767768	total: 2.34s	remaining: 3.48s
# 300:	learn: 0.0727810	total: 3.49s	remaining: 2.31s
# 400:	learn: 0.0689219	total: 4.65s	remaining: 1.15s
# 499:	learn: 0.0655776	total: 5.8s	remaining: 0us
# 0:	learn: 0.4013128	total: 12.7ms	remaining: 6.32s
# 100:	learn: 0.0771416	total: 1.18s	remaining: 4.66s
# 200:	learn: 0.0706426	total: 2.35s	remaining: 3.49s
# 300:	learn: 0.0666829	total: 3.49s	remaining: 2.31s
# 400:	learn: 0.0632167	total: 4.66s	remaining: 1.15s
# 499:	learn: 0.0600880	total: 5.8s	remaining: 0us
# 0:	learn: 0.3299577	total: 13.1ms	remaining: 6.54s
# 100:	learn: 0.0799273	total: 1.17s	remaining: 4.63s
# 200:	learn: 0.0742707	total: 2.33s	remaining: 3.46s
# 300:	learn: 0.0702988	total: 3.48s	remaining: 2.3s
# 400:	learn: 0.0666054	total: 4.65s	remaining: 1.15s
# 499:	learn: 0.0633268	total: 5.79s	remaining: 0us
# 0:	learn: 0.6678472	total: 15ms	remaining: 7.5s
# 100:	learn: 0.1193258	total: 1.37s	remaining: 5.4s
# 200:	learn: 0.0970030	total: 2.71s	remaining: 4.03s
# 300:	learn: 0.0918712	total: 4.05s	remaining: 2.68s
# 400:	learn: 0.0892347	total: 5.4s	remaining: 1.33s
# 499:	learn: 0.0876718	total: 6.76s	remaining: 0us
# 0:	learn: 0.6721476	total: 15.1ms	remaining: 7.51s
# 100:	learn: 0.1115046	total: 1.38s	remaining: 5.46s
# 200:	learn: 0.0907731	total: 2.74s	remaining: 4.08s
# 300:	learn: 0.0853253	total: 4.09s	remaining: 2.71s
# 400:	learn: 0.0829358	total: 5.44s	remaining: 1.34s
# 499:	learn: 0.0813192	total: 6.76s	remaining: 0us
# 0:	learn: 0.6650940	total: 14.6ms	remaining: 7.28s
# 100:	learn: 0.1103843	total: 1.39s	remaining: 5.47s
# 200:	learn: 0.0913546	total: 2.75s	remaining: 4.09s
# 300:	learn: 0.0870365	total: 4.1s	remaining: 2.71s
# 400:	learn: 0.0849131	total: 5.45s	remaining: 1.34s
# 499:	learn: 0.0836496	total: 6.78s	remaining: 0us
# 0:	learn: 0.2905801	total: 12.5ms	remaining: 6.26s
# 100:	learn: 0.0806794	total: 1.17s	remaining: 4.63s
# 200:	learn: 0.0736835	total: 2.33s	remaining: 3.47s
# 300:	learn: 0.0683597	total: 3.5s	remaining: 2.31s
# 400:	learn: 0.0639808	total: 4.66s	remaining: 1.15s
# 499:	learn: 0.0602738	total: 5.82s	remaining: 0us
# 0:	learn: 0.3279854	total: 13.5ms	remaining: 6.73s
# 100:	learn: 0.0744648	total: 1.2s	remaining: 4.74s
# 200:	learn: 0.0670162	total: 2.38s	remaining: 3.54s
# 300:	learn: 0.0621471	total: 3.54s	remaining: 2.34s
# 400:	learn: 0.0582506	total: 4.72s	remaining: 1.17s
# 499:	learn: 0.0547925	total: 5.9s	remaining: 0us
# 0:	learn: 0.2563190	total: 13.2ms	remaining: 6.61s
# 100:	learn: 0.0782823	total: 1.2s	remaining: 4.74s
# 200:	learn: 0.0716593	total: 2.38s	remaining: 3.54s
# 300:	learn: 0.0667093	total: 3.59s	remaining: 2.37s
# 400:	learn: 0.0624218	total: 4.76s	remaining: 1.18s
# 499:	learn: 0.0584951	total: 5.91s	remaining: 0us
# 0:	learn: 0.4116407	total: 12.9ms	remaining: 6.46s
# 100:	learn: 0.0847170	total: 1.2s	remaining: 4.75s
# 200:	learn: 0.0794411	total: 2.38s	remaining: 3.55s
# 300:	learn: 0.0755339	total: 3.58s	remaining: 2.37s
# 400:	learn: 0.0721497	total: 4.77s	remaining: 1.18s
# 499:	learn: 0.0699807	total: 5.95s	remaining: 0us
# 0:	learn: 0.4460365	total: 12.6ms	remaining: 6.27s
# 100:	learn: 0.0784853	total: 1.2s	remaining: 4.75s
# 200:	learn: 0.0727939	total: 2.4s	remaining: 3.57s
# 300:	learn: 0.0690802	total: 3.59s	remaining: 2.37s
# 400:	learn: 0.0658649	total: 4.76s	remaining: 1.18s
# 499:	learn: 0.0634187	total: 5.93s	remaining: 0us
# 0:	learn: 0.3800083	total: 13.3ms	remaining: 6.64s
# 100:	learn: 0.0815379	total: 1.19s	remaining: 4.72s
# 200:	learn: 0.0771050	total: 2.37s	remaining: 3.52s
# 300:	learn: 0.0735578	total: 3.54s	remaining: 2.34s
# 400:	learn: 0.0700424	total: 4.73s	remaining: 1.17s
# 499:	learn: 0.0673607	total: 5.91s	remaining: 0us
# 0:	learn: 0.5223864	total: 15.4ms	remaining: 7.71s
# 100:	learn: 0.0848312	total: 1.36s	remaining: 5.39s
# 200:	learn: 0.0785845	total: 2.69s	remaining: 4s
# 300:	learn: 0.0739623	total: 4.04s	remaining: 2.67s
# 400:	learn: 0.0699196	total: 5.41s	remaining: 1.33s
# 499:	learn: 0.0662877	total: 6.75s	remaining: 0us
# 0:	learn: 0.5486367	total: 15.4ms	remaining: 7.68s
# 100:	learn: 0.0786155	total: 1.38s	remaining: 5.46s
# 200:	learn: 0.0727539	total: 2.76s	remaining: 4.1s
# 300:	learn: 0.0672352	total: 4.13s	remaining: 2.73s
# 400:	learn: 0.0632018	total: 5.5s	remaining: 1.36s
# 499:	learn: 0.0600935	total: 6.84s	remaining: 0us
# 0:	learn: 0.5051659	total: 15.7ms	remaining: 7.83s
# 100:	learn: 0.0815433	total: 1.39s	remaining: 5.5s
# 200:	learn: 0.0761972	total: 2.77s	remaining: 4.12s
# 300:	learn: 0.0721939	total: 4.15s	remaining: 2.74s
# 400:	learn: 0.0684037	total: 5.53s	remaining: 1.36s
# 499:	learn: 0.0646658	total: 6.9s	remaining: 0us
# 0:	learn: 0.6677680	total: 13.1ms	remaining: 6.53s
# 100:	learn: 0.1274483	total: 1.21s	remaining: 4.8s
# 200:	learn: 0.1008065	total: 2.41s	remaining: 3.59s
# 300:	learn: 0.0941612	total: 3.62s	remaining: 2.39s
# 400:	learn: 0.0918188	total: 4.8s	remaining: 1.19s
# 499:	learn: 0.0904695	total: 5.97s	remaining: 0us
# 0:	learn: 0.6717347	total: 13.2ms	remaining: 6.57s
# 100:	learn: 0.1182744	total: 1.2s	remaining: 4.75s
# 200:	learn: 0.0939751	total: 2.39s	remaining: 3.56s
# 300:	learn: 0.0880174	total: 3.6s	remaining: 2.38s
# 400:	learn: 0.0856168	total: 4.78s	remaining: 1.18s
# 499:	learn: 0.0841413	total: 5.95s	remaining: 0us
# 0:	learn: 0.6637606	total: 12.1ms	remaining: 6.05s
# 100:	learn: 0.1189335	total: 1.18s	remaining: 4.65s
# 200:	learn: 0.0938604	total: 2.37s	remaining: 3.52s
# 300:	learn: 0.0888985	total: 3.55s	remaining: 2.35s
# 400:	learn: 0.0870100	total: 4.76s	remaining: 1.18s
# 499:	learn: 0.0859171	total: 5.94s	remaining: 0us
# 0:	learn: 0.5223864	total: 15.3ms	remaining: 15.2s
# 100:	learn: 0.0848312	total: 1.39s	remaining: 12.4s
# 200:	learn: 0.0785845	total: 2.77s	remaining: 11s
# 300:	learn: 0.0739623	total: 4.14s	remaining: 9.61s
# 400:	learn: 0.0699196	total: 5.52s	remaining: 8.25s
# 500:	learn: 0.0662340	total: 6.89s	remaining: 6.87s
# 600:	learn: 0.0630000	total: 8.25s	remaining: 5.47s
# 700:	learn: 0.0604440	total: 9.58s	remaining: 4.09s
# 800:	learn: 0.0577545	total: 10.9s	remaining: 2.72s
# 900:	learn: 0.0556195	total: 12.3s	remaining: 1.35s
# 999:	learn: 0.0536488	total: 13.6s	remaining: 0us
# 0:	learn: 0.5486367	total: 15.3ms	remaining: 15.3s
# 100:	learn: 0.0786155	total: 1.38s	remaining: 12.3s
# 200:	learn: 0.0727539	total: 2.73s	remaining: 10.8s
# 300:	learn: 0.0672352	total: 4.07s	remaining: 9.46s
# 400:	learn: 0.0632018	total: 5.42s	remaining: 8.1s
# 500:	learn: 0.0600639	total: 6.8s	remaining: 6.77s
# 600:	learn: 0.0573192	total: 8.15s	remaining: 5.41s
# 700:	learn: 0.0550555	total: 9.52s	remaining: 4.06s
# 800:	learn: 0.0528810	total: 10.9s	remaining: 2.7s
# 900:	learn: 0.0508488	total: 12.2s	remaining: 1.34s
# 999:	learn: 0.0488756	total: 13.6s	remaining: 0us
# 0:	learn: 0.5051659	total: 15.7ms	remaining: 15.7s
# 100:	learn: 0.0815433	total: 1.4s	remaining: 12.5s
# 200:	learn: 0.0761972	total: 2.76s	remaining: 11s
# 300:	learn: 0.0721939	total: 4.14s	remaining: 9.61s
# 400:	learn: 0.0684037	total: 5.51s	remaining: 8.23s
# 500:	learn: 0.0646505	total: 6.88s	remaining: 6.85s
# 600:	learn: 0.0619457	total: 8.23s	remaining: 5.46s
# 700:	learn: 0.0591270	total: 9.6s	remaining: 4.09s
# 800:	learn: 0.0567409	total: 11s	remaining: 2.72s
# 900:	learn: 0.0544927	total: 12.3s	remaining: 1.36s
# 999:	learn: 0.0526314	total: 13.7s	remaining: 0us
# 0:	learn: 0.3256655	total: 14.9ms	remaining: 14.9s
# 100:	learn: 0.0757980	total: 1.41s	remaining: 12.5s
# 200:	learn: 0.0660062	total: 2.77s	remaining: 11s
# 300:	learn: 0.0590057	total: 4.14s	remaining: 9.61s
# 400:	learn: 0.0537752	total: 5.5s	remaining: 8.22s
# 500:	learn: 0.0492327	total: 6.88s	remaining: 6.85s
# 600:	learn: 0.0452239	total: 8.24s	remaining: 5.47s
# 700:	learn: 0.0416028	total: 9.58s	remaining: 4.09s
# 800:	learn: 0.0387314	total: 11s	remaining: 2.72s
# 900:	learn: 0.0365750	total: 12.3s	remaining: 1.35s
# 999:	learn: 0.0347373	total: 13.6s	remaining: 0us
# 0:	learn: 0.3657866	total: 14.9ms	remaining: 14.9s
# 100:	learn: 0.0694348	total: 1.39s	remaining: 12.4s
# 200:	learn: 0.0593979	total: 2.77s	remaining: 11s
# 300:	learn: 0.0534441	total: 4.14s	remaining: 9.61s
# 400:	learn: 0.0477534	total: 5.51s	remaining: 8.23s
# 500:	learn: 0.0439222	total: 6.87s	remaining: 6.84s
# 600:	learn: 0.0404986	total: 8.24s	remaining: 5.47s
# 700:	learn: 0.0374382	total: 9.6s	remaining: 4.1s
# 800:	learn: 0.0348075	total: 11s	remaining: 2.72s
# 900:	learn: 0.0326958	total: 12.3s	remaining: 1.35s
# 999:	learn: 0.0308667	total: 13.6s	remaining: 0us
# 0:	learn: 0.3003119	total: 15.8ms	remaining: 15.8s
# 100:	learn: 0.0729378	total: 1.38s	remaining: 12.3s
# 200:	learn: 0.0638482	total: 2.75s	remaining: 10.9s
# 300:	learn: 0.0570525	total: 4.12s	remaining: 9.56s
# 400:	learn: 0.0519853	total: 5.47s	remaining: 8.17s
# 500:	learn: 0.0474768	total: 6.82s	remaining: 6.79s
# 600:	learn: 0.0441992	total: 8.15s	remaining: 5.41s
# 700:	learn: 0.0411386	total: 9.5s	remaining: 4.05s
# 800:	learn: 0.0384185	total: 10.8s	remaining: 2.69s
# 900:	learn: 0.0362080	total: 12.2s	remaining: 1.34s
# 999:	learn: 0.0342798	total: 13.5s	remaining: 0us
# 0:	learn: 0.5235246	total: 12.8ms	remaining: 12.8s
# 100:	learn: 0.0886360	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0841264	total: 2.38s	remaining: 9.46s
# 300:	learn: 0.0809345	total: 3.56s	remaining: 8.27s
# 400:	learn: 0.0784786	total: 4.75s	remaining: 7.09s
# 500:	learn: 0.0761672	total: 5.93s	remaining: 5.91s
# 600:	learn: 0.0745044	total: 7.1s	remaining: 4.71s
# 700:	learn: 0.0728518	total: 8.26s	remaining: 3.52s
# 800:	learn: 0.0711589	total: 9.45s	remaining: 2.35s
# 900:	learn: 0.0696240	total: 10.6s	remaining: 1.17s
# 999:	learn: 0.0683188	total: 11.8s	remaining: 0us
# 0:	learn: 0.5472116	total: 12.9ms	remaining: 12.9s
# 100:	learn: 0.0820938	total: 1.21s	remaining: 10.7s
# 200:	learn: 0.0779618	total: 2.4s	remaining: 9.54s
# 300:	learn: 0.0746989	total: 3.59s	remaining: 8.33s
# 400:	learn: 0.0721223	total: 4.78s	remaining: 7.14s
# 500:	learn: 0.0701840	total: 5.99s	remaining: 5.96s
# 600:	learn: 0.0682672	total: 7.17s	remaining: 4.76s
# 700:	learn: 0.0666116	total: 8.35s	remaining: 3.56s
# 800:	learn: 0.0650331	total: 9.53s	remaining: 2.37s
# 900:	learn: 0.0636434	total: 10.7s	remaining: 1.18s
# 999:	learn: 0.0625178	total: 11.9s	remaining: 0us
# 0:	learn: 0.5001804	total: 13.2ms	remaining: 13.2s
# 100:	learn: 0.0843032	total: 1.21s	remaining: 10.8s
# 200:	learn: 0.0806142	total: 2.41s	remaining: 9.58s
# 300:	learn: 0.0783652	total: 3.59s	remaining: 8.33s
# 400:	learn: 0.0759809	total: 4.77s	remaining: 7.13s
# 500:	learn: 0.0740424	total: 5.98s	remaining: 5.96s
# 600:	learn: 0.0722093	total: 7.17s	remaining: 4.76s
# 700:	learn: 0.0702950	total: 8.34s	remaining: 3.56s
# 800:	learn: 0.0686676	total: 9.52s	remaining: 2.36s
# 900:	learn: 0.0671911	total: 10.7s	remaining: 1.17s
# 999:	learn: 0.0657512	total: 11.9s	remaining: 0us
# 0:	learn: 0.2621866	total: 15.6ms	remaining: 7.79s
# 100:	learn: 0.0720850	total: 1.38s	remaining: 5.43s
# 200:	learn: 0.0607639	total: 2.76s	remaining: 4.11s
# 300:	learn: 0.0532356	total: 4.13s	remaining: 2.73s
# 400:	learn: 0.0470655	total: 5.49s	remaining: 1.35s
# 499:	learn: 0.0424447	total: 6.84s	remaining: 0us
# 0:	learn: 0.3003894	total: 14.7ms	remaining: 7.31s
# 100:	learn: 0.0649957	total: 1.39s	remaining: 5.49s
# 200:	learn: 0.0548757	total: 2.75s	remaining: 4.1s
# 300:	learn: 0.0479560	total: 4.12s	remaining: 2.73s
# 400:	learn: 0.0420100	total: 5.51s	remaining: 1.36s
# 499:	learn: 0.0378263	total: 6.88s	remaining: 0us
# 0:	learn: 0.2377778	total: 15.5ms	remaining: 7.73s
# 100:	learn: 0.0693063	total: 1.38s	remaining: 5.44s
# 200:	learn: 0.0590064	total: 2.75s	remaining: 4.1s
# 300:	learn: 0.0514773	total: 4.12s	remaining: 2.73s
# 400:	learn: 0.0456039	total: 5.49s	remaining: 1.36s
# 499:	learn: 0.0416844	total: 6.84s	remaining: 0us
# 0:	learn: 0.4633456	total: 13.5ms	remaining: 6.73s
# 100:	learn: 0.0865143	total: 1.2s	remaining: 4.75s
# 200:	learn: 0.0815056	total: 2.39s	remaining: 3.56s
# 300:	learn: 0.0776168	total: 3.56s	remaining: 2.36s
# 400:	learn: 0.0748980	total: 4.73s	remaining: 1.17s
# 499:	learn: 0.0723496	total: 5.89s	remaining: 0us
# 0:	learn: 0.4933728	total: 13.4ms	remaining: 6.69s
# 100:	learn: 0.0804592	total: 1.19s	remaining: 4.71s
# 200:	learn: 0.0753011	total: 2.37s	remaining: 3.53s
# 300:	learn: 0.0712857	total: 3.56s	remaining: 2.35s
# 400:	learn: 0.0684501	total: 4.76s	remaining: 1.17s
# 499:	learn: 0.0661198	total: 5.94s	remaining: 0us
# 0:	learn: 0.4341924	total: 14.3ms	remaining: 7.15s
# 100:	learn: 0.0827971	total: 1.2s	remaining: 4.75s
# 200:	learn: 0.0786819	total: 2.39s	remaining: 3.56s
# 300:	learn: 0.0754930	total: 3.57s	remaining: 2.36s
# 400:	learn: 0.0726594	total: 4.78s	remaining: 1.18s
# 499:	learn: 0.0701517	total: 5.95s	remaining: 0us
# 0:	learn: 0.4116407	total: 13ms	remaining: 13s
# 100:	learn: 0.0847170	total: 1.19s	remaining: 10.6s
# 200:	learn: 0.0794411	total: 2.4s	remaining: 9.52s
# 300:	learn: 0.0755339	total: 3.56s	remaining: 8.26s
# 400:	learn: 0.0721497	total: 4.74s	remaining: 7.08s
# 500:	learn: 0.0699686	total: 5.92s	remaining: 5.9s
# 600:	learn: 0.0672040	total: 7.08s	remaining: 4.7s
# 700:	learn: 0.0647358	total: 8.25s	remaining: 3.52s
# 800:	learn: 0.0626352	total: 9.41s	remaining: 2.34s
# 900:	learn: 0.0607424	total: 10.6s	remaining: 1.16s
# 999:	learn: 0.0592109	total: 11.7s	remaining: 0us
# 0:	learn: 0.4460365	total: 12.9ms	remaining: 12.9s
# 100:	learn: 0.0784853	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0727939	total: 2.38s	remaining: 9.48s
# 300:	learn: 0.0690802	total: 3.56s	remaining: 8.26s
# 400:	learn: 0.0658649	total: 4.74s	remaining: 7.08s
# 500:	learn: 0.0634042	total: 5.93s	remaining: 5.91s
# 600:	learn: 0.0615235	total: 7.11s	remaining: 4.72s
# 700:	learn: 0.0597248	total: 8.28s	remaining: 3.53s
# 800:	learn: 0.0579567	total: 9.43s	remaining: 2.34s
# 900:	learn: 0.0562015	total: 10.6s	remaining: 1.16s
# 999:	learn: 0.0546759	total: 11.7s	remaining: 0us
# 0:	learn: 0.3800083	total: 12.9ms	remaining: 12.9s
# 100:	learn: 0.0815379	total: 1.21s	remaining: 10.8s
# 200:	learn: 0.0771050	total: 2.39s	remaining: 9.5s
# 300:	learn: 0.0735578	total: 3.55s	remaining: 8.25s
# 400:	learn: 0.0700424	total: 4.72s	remaining: 7.05s
# 500:	learn: 0.0673452	total: 5.9s	remaining: 5.88s
# 600:	learn: 0.0648376	total: 7.07s	remaining: 4.7s
# 700:	learn: 0.0626306	total: 8.24s	remaining: 3.52s
# 800:	learn: 0.0607007	total: 9.42s	remaining: 2.34s
# 900:	learn: 0.0589811	total: 10.6s	remaining: 1.17s
# 999:	learn: 0.0573346	total: 11.8s	remaining: 0us
# 0:	learn: 0.2622916	total: 13.3ms	remaining: 13.3s
# 100:	learn: 0.0797995	total: 1.21s	remaining: 10.8s
# 200:	learn: 0.0726753	total: 2.39s	remaining: 9.51s
# 300:	learn: 0.0673441	total: 3.57s	remaining: 8.29s
# 400:	learn: 0.0626647	total: 4.75s	remaining: 7.1s
# 500:	learn: 0.0588656	total: 5.93s	remaining: 5.9s
# 600:	learn: 0.0556872	total: 7.11s	remaining: 4.72s
# 700:	learn: 0.0530040	total: 8.28s	remaining: 3.53s
# 800:	learn: 0.0507596	total: 9.44s	remaining: 2.35s
# 900:	learn: 0.0490419	total: 10.6s	remaining: 1.16s
# 999:	learn: 0.0470075	total: 11.8s	remaining: 0us
# 0:	learn: 0.2986236	total: 13.4ms	remaining: 13.4s
# 100:	learn: 0.0736352	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0664192	total: 2.39s	remaining: 9.52s
# 300:	learn: 0.0610833	total: 3.59s	remaining: 8.34s
# 400:	learn: 0.0570850	total: 4.78s	remaining: 7.13s
# 500:	learn: 0.0537768	total: 5.96s	remaining: 5.94s
# 600:	learn: 0.0508092	total: 7.14s	remaining: 4.74s
# 700:	learn: 0.0481423	total: 8.31s	remaining: 3.54s
# 800:	learn: 0.0459504	total: 9.48s	remaining: 2.36s
# 900:	learn: 0.0439214	total: 10.7s	remaining: 1.17s
# 999:	learn: 0.0419234	total: 11.8s	remaining: 0us
# 0:	learn: 0.2304999	total: 12.8ms	remaining: 12.8s
# 100:	learn: 0.0774727	total: 1.22s	remaining: 10.8s
# 200:	learn: 0.0709631	total: 2.42s	remaining: 9.6s
# 300:	learn: 0.0657038	total: 3.61s	remaining: 8.39s
# 400:	learn: 0.0612371	total: 4.8s	remaining: 7.16s
# 500:	learn: 0.0576635	total: 5.99s	remaining: 5.96s
# 600:	learn: 0.0540812	total: 7.17s	remaining: 4.76s
# 700:	learn: 0.0511945	total: 8.34s	remaining: 3.56s
# 800:	learn: 0.0488424	total: 9.5s	remaining: 2.36s
# 900:	learn: 0.0465627	total: 10.7s	remaining: 1.17s
# 999:	learn: 0.0446461	total: 11.8s	remaining: 0us
# 0:	learn: 0.3247799	total: 13.1ms	remaining: 6.56s
# 100:	learn: 0.0817844	total: 1.2s	remaining: 4.76s
# 200:	learn: 0.0750640	total: 2.4s	remaining: 3.57s
# 300:	learn: 0.0703273	total: 3.59s	remaining: 2.38s
# 400:	learn: 0.0668321	total: 4.79s	remaining: 1.18s
# 499:	learn: 0.0632233	total: 5.96s	remaining: 0us
# 0:	learn: 0.3624771	total: 13.2ms	remaining: 6.57s
# 100:	learn: 0.0761798	total: 1.21s	remaining: 4.78s
# 200:	learn: 0.0689597	total: 2.39s	remaining: 3.56s
# 300:	learn: 0.0641809	total: 3.57s	remaining: 2.36s
# 400:	learn: 0.0604241	total: 4.76s	remaining: 1.18s
# 499:	learn: 0.0571556	total: 5.93s	remaining: 0us
# 0:	learn: 0.2898111	total: 13.8ms	remaining: 6.89s
# 100:	learn: 0.0788233	total: 1.21s	remaining: 4.76s
# 200:	learn: 0.0732022	total: 2.4s	remaining: 3.57s
# 300:	learn: 0.0682458	total: 3.59s	remaining: 2.37s
# 400:	learn: 0.0641196	total: 4.78s	remaining: 1.18s
# 499:	learn: 0.0603492	total: 5.96s	remaining: 0us
# 0:	learn: 0.5907841	total: 16ms	remaining: 7.99s
# 100:	learn: 0.0884117	total: 1.4s	remaining: 5.52s
# 200:	learn: 0.0836981	total: 2.75s	remaining: 4.1s
# 300:	learn: 0.0802853	total: 4.1s	remaining: 2.71s
# 400:	learn: 0.0771993	total: 5.47s	remaining: 1.35s
# 499:	learn: 0.0742441	total: 6.82s	remaining: 0us
# 0:	learn: 0.6075321	total: 15.2ms	remaining: 7.6s
# 100:	learn: 0.0821910	total: 1.39s	remaining: 5.48s
# 200:	learn: 0.0777157	total: 2.76s	remaining: 4.1s
# 300:	learn: 0.0742552	total: 4.12s	remaining: 2.72s
# 400:	learn: 0.0711205	total: 5.48s	remaining: 1.35s
# 499:	learn: 0.0682995	total: 6.84s	remaining: 0us
# 0:	learn: 0.5797488	total: 15.7ms	remaining: 7.84s
# 100:	learn: 0.0843889	total: 1.39s	remaining: 5.49s
# 200:	learn: 0.0806046	total: 2.78s	remaining: 4.13s
# 300:	learn: 0.0775457	total: 4.15s	remaining: 2.74s
# 400:	learn: 0.0749684	total: 5.52s	remaining: 1.36s
# 499:	learn: 0.0725403	total: 6.86s	remaining: 0us
# 0:	learn: 0.4633456	total: 14.3ms	remaining: 14.3s
# 100:	learn: 0.0865143	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0815056	total: 2.37s	remaining: 9.43s
# 300:	learn: 0.0776168	total: 3.55s	remaining: 8.24s
# 400:	learn: 0.0748980	total: 4.74s	remaining: 7.08s
# 500:	learn: 0.0723413	total: 5.91s	remaining: 5.89s
# 600:	learn: 0.0698422	total: 7.08s	remaining: 4.7s
# 700:	learn: 0.0679873	total: 8.25s	remaining: 3.52s
# 800:	learn: 0.0660085	total: 9.42s	remaining: 2.34s
# 900:	learn: 0.0642948	total: 10.6s	remaining: 1.17s
# 999:	learn: 0.0624787	total: 11.8s	remaining: 0us
# 0:	learn: 0.4933728	total: 13.2ms	remaining: 13.2s
# 100:	learn: 0.0804592	total: 1.24s	remaining: 11s
# 200:	learn: 0.0753011	total: 2.44s	remaining: 9.72s
# 300:	learn: 0.0712857	total: 3.67s	remaining: 8.52s
# 400:	learn: 0.0684501	total: 4.86s	remaining: 7.26s
# 500:	learn: 0.0661002	total: 6.05s	remaining: 6.03s
# 600:	learn: 0.0641082	total: 7.22s	remaining: 4.79s
# 700:	learn: 0.0622446	total: 8.4s	remaining: 3.58s
# 800:	learn: 0.0606059	total: 9.58s	remaining: 2.38s
# 900:	learn: 0.0590200	total: 10.8s	remaining: 1.18s
# 999:	learn: 0.0574704	total: 11.9s	remaining: 0us
# 0:	learn: 0.4341924	total: 13.8ms	remaining: 13.8s
# 100:	learn: 0.0827971	total: 1.22s	remaining: 10.9s
# 200:	learn: 0.0786819	total: 2.43s	remaining: 9.67s
# 300:	learn: 0.0754930	total: 3.64s	remaining: 8.45s
# 400:	learn: 0.0726594	total: 4.83s	remaining: 7.22s
# 500:	learn: 0.0701384	total: 6.03s	remaining: 6s
# 600:	learn: 0.0678267	total: 7.21s	remaining: 4.79s
# 700:	learn: 0.0655593	total: 8.42s	remaining: 3.59s
# 800:	learn: 0.0637758	total: 9.6s	remaining: 2.38s
# 900:	learn: 0.0617917	total: 10.8s	remaining: 1.18s
# 999:	learn: 0.0602373	total: 12s	remaining: 0us
# 0:	learn: 0.3653945	total: 15.2ms	remaining: 15.2s
# 100:	learn: 0.0771066	total: 1.39s	remaining: 12.4s
# 200:	learn: 0.0683093	total: 2.77s	remaining: 11s
# 300:	learn: 0.0622240	total: 4.13s	remaining: 9.59s
# 400:	learn: 0.0570075	total: 5.52s	remaining: 8.24s
# 500:	learn: 0.0526204	total: 6.9s	remaining: 6.88s
# 600:	learn: 0.0495943	total: 8.26s	remaining: 5.48s
# 700:	learn: 0.0462764	total: 9.63s	remaining: 4.11s
# 800:	learn: 0.0436210	total: 11s	remaining: 2.73s
# 900:	learn: 0.0411684	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0391474	total: 13.7s	remaining: 0us
# 0:	learn: 0.4046617	total: 16ms	remaining: 16s
# 100:	learn: 0.0709586	total: 1.41s	remaining: 12.6s
# 200:	learn: 0.0624039	total: 2.84s	remaining: 11.3s
# 300:	learn: 0.0560620	total: 4.24s	remaining: 9.85s
# 400:	learn: 0.0514486	total: 5.65s	remaining: 8.44s
# 500:	learn: 0.0475489	total: 7.03s	remaining: 7s
# 600:	learn: 0.0441410	total: 8.4s	remaining: 5.58s
# 700:	learn: 0.0412651	total: 9.77s	remaining: 4.17s
# 800:	learn: 0.0387129	total: 11.1s	remaining: 2.77s
# 900:	learn: 0.0365719	total: 12.5s	remaining: 1.37s
# 999:	learn: 0.0343321	total: 13.8s	remaining: 0us
# 0:	learn: 0.3406042	total: 15.8ms	remaining: 15.8s
# 100:	learn: 0.0755075	total: 1.41s	remaining: 12.5s
# 200:	learn: 0.0664271	total: 2.79s	remaining: 11.1s
# 300:	learn: 0.0606092	total: 4.16s	remaining: 9.66s
# 400:	learn: 0.0558898	total: 5.54s	remaining: 8.27s
# 500:	learn: 0.0509228	total: 6.91s	remaining: 6.88s
# 600:	learn: 0.0477082	total: 8.28s	remaining: 5.5s
# 700:	learn: 0.0444598	total: 9.65s	remaining: 4.12s
# 800:	learn: 0.0419522	total: 11s	remaining: 2.73s
# 900:	learn: 0.0394890	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0375050	total: 13.7s	remaining: 0us
# 0:	learn: 0.2892176	total: 15.2ms	remaining: 7.6s
# 100:	learn: 0.0719499	total: 1.41s	remaining: 5.55s
# 200:	learn: 0.0611204	total: 2.78s	remaining: 4.13s
# 300:	learn: 0.0532888	total: 4.15s	remaining: 2.74s
# 400:	learn: 0.0471815	total: 5.52s	remaining: 1.36s
# 499:	learn: 0.0430593	total: 6.86s	remaining: 0us
# 0:	learn: 0.3297295	total: 15.5ms	remaining: 7.71s
# 100:	learn: 0.0660613	total: 1.41s	remaining: 5.56s
# 200:	learn: 0.0561126	total: 2.77s	remaining: 4.12s
# 300:	learn: 0.0485557	total: 4.14s	remaining: 2.74s
# 400:	learn: 0.0432461	total: 5.5s	remaining: 1.36s
# 499:	learn: 0.0392241	total: 6.85s	remaining: 0us
# 0:	learn: 0.2628672	total: 15.4ms	remaining: 7.69s
# 100:	learn: 0.0699157	total: 1.41s	remaining: 5.57s
# 200:	learn: 0.0592251	total: 2.79s	remaining: 4.16s
# 300:	learn: 0.0524403	total: 4.17s	remaining: 2.76s
# 400:	learn: 0.0466270	total: 5.54s	remaining: 1.37s
# 499:	learn: 0.0421381	total: 6.88s	remaining: 0us
# 0:	learn: 0.5918438	total: 16ms	remaining: 8s
# 100:	learn: 0.0885010	total: 1.39s	remaining: 5.5s
# 200:	learn: 0.0840359	total: 2.77s	remaining: 4.11s
# 300:	learn: 0.0807702	total: 4.13s	remaining: 2.73s
# 400:	learn: 0.0776283	total: 5.5s	remaining: 1.36s
# 499:	learn: 0.0750420	total: 6.85s	remaining: 0us
# 0:	learn: 0.6081334	total: 15.1ms	remaining: 7.54s
# 100:	learn: 0.0824122	total: 1.39s	remaining: 5.5s
# 200:	learn: 0.0778945	total: 2.77s	remaining: 4.12s
# 300:	learn: 0.0746075	total: 4.14s	remaining: 2.73s
# 400:	learn: 0.0717102	total: 5.5s	remaining: 1.36s
# 499:	learn: 0.0689443	total: 6.85s	remaining: 0us
# 0:	learn: 0.5814513	total: 15.4ms	remaining: 7.71s
# 100:	learn: 0.0847275	total: 1.38s	remaining: 5.46s
# 200:	learn: 0.0811075	total: 2.75s	remaining: 4.09s
# 300:	learn: 0.0781650	total: 4.12s	remaining: 2.73s
# 400:	learn: 0.0755196	total: 5.48s	remaining: 1.35s
# 499:	learn: 0.0731182	total: 6.84s	remaining: 0us
# 0:	learn: 0.5915381	total: 12.8ms	remaining: 6.4s
# 100:	learn: 0.0914868	total: 1.21s	remaining: 4.76s
# 200:	learn: 0.0879847	total: 2.4s	remaining: 3.58s
# 300:	learn: 0.0854613	total: 3.59s	remaining: 2.38s
# 400:	learn: 0.0833859	total: 4.79s	remaining: 1.18s
# 499:	learn: 0.0816880	total: 5.97s	remaining: 0us
# 0:	learn: 0.6065946	total: 12.4ms	remaining: 6.19s
# 100:	learn: 0.0850269	total: 1.21s	remaining: 4.79s
# 200:	learn: 0.0813142	total: 2.4s	remaining: 3.57s
# 300:	learn: 0.0791399	total: 3.59s	remaining: 2.37s
# 400:	learn: 0.0770633	total: 4.77s	remaining: 1.18s
# 499:	learn: 0.0751776	total: 5.95s	remaining: 0us
# 0:	learn: 0.5764976	total: 14.2ms	remaining: 7.11s
# 100:	learn: 0.0867428	total: 1.2s	remaining: 4.75s
# 200:	learn: 0.0835913	total: 2.39s	remaining: 3.56s
# 300:	learn: 0.0814804	total: 3.57s	remaining: 2.36s
# 400:	learn: 0.0797925	total: 4.75s	remaining: 1.17s
# 499:	learn: 0.0784568	total: 5.91s	remaining: 0us
# 0:	learn: 0.2600613	total: 16ms	remaining: 16s
# 100:	learn: 0.0697370	total: 1.39s	remaining: 12.4s
# 200:	learn: 0.0589882	total: 2.76s	remaining: 11s
# 300:	learn: 0.0513400	total: 4.13s	remaining: 9.58s
# 400:	learn: 0.0452002	total: 5.48s	remaining: 8.19s
# 500:	learn: 0.0403924	total: 6.86s	remaining: 6.83s
# 600:	learn: 0.0364771	total: 8.21s	remaining: 5.45s
# 700:	learn: 0.0334874	total: 9.56s	remaining: 4.08s
# 800:	learn: 0.0308714	total: 10.9s	remaining: 2.71s
# 900:	learn: 0.0286786	total: 12.3s	remaining: 1.35s
# 999:	learn: 0.0267462	total: 13.6s	remaining: 0us
# 0:	learn: 0.2990429	total: 14.8ms	remaining: 14.8s
# 100:	learn: 0.0643271	total: 1.39s	remaining: 12.4s
# 200:	learn: 0.0533173	total: 2.76s	remaining: 11s
# 300:	learn: 0.0456920	total: 4.13s	remaining: 9.58s
# 400:	learn: 0.0399406	total: 5.5s	remaining: 8.22s
# 500:	learn: 0.0354316	total: 6.86s	remaining: 6.83s
# 600:	learn: 0.0317197	total: 8.2s	remaining: 5.44s
# 700:	learn: 0.0287616	total: 9.58s	remaining: 4.08s
# 800:	learn: 0.0264450	total: 11s	remaining: 2.72s
# 900:	learn: 0.0247852	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0230879	total: 13.7s	remaining: 0us
# 0:	learn: 0.2345595	total: 14.7ms	remaining: 14.6s
# 100:	learn: 0.0692863	total: 1.41s	remaining: 12.5s
# 200:	learn: 0.0580807	total: 2.79s	remaining: 11.1s
# 300:	learn: 0.0507758	total: 4.15s	remaining: 9.64s
# 400:	learn: 0.0448126	total: 5.51s	remaining: 8.24s
# 500:	learn: 0.0400812	total: 6.91s	remaining: 6.88s
# 600:	learn: 0.0363268	total: 8.25s	remaining: 5.48s
# 700:	learn: 0.0330897	total: 9.61s	remaining: 4.1s
# 800:	learn: 0.0304993	total: 11s	remaining: 2.73s
# 900:	learn: 0.0282473	total: 12.3s	remaining: 1.36s
# 999:	learn: 0.0266372	total: 13.7s	remaining: 0us
# 0:	learn: 0.2363782	total: 12.6ms	remaining: 6.28s
# 100:	learn: 0.0783339	total: 1.21s	remaining: 4.79s
# 200:	learn: 0.0703095	total: 2.41s	remaining: 3.58s
# 300:	learn: 0.0646287	total: 3.6s	remaining: 2.38s
# 400:	learn: 0.0598960	total: 4.79s	remaining: 1.18s
# 499:	learn: 0.0554100	total: 5.98s	remaining: 0us
# 0:	learn: 0.2706061	total: 13.3ms	remaining: 6.63s
# 100:	learn: 0.0718709	total: 1.21s	remaining: 4.78s
# 200:	learn: 0.0639665	total: 2.41s	remaining: 3.58s
# 300:	learn: 0.0584950	total: 3.61s	remaining: 2.39s
# 400:	learn: 0.0547447	total: 4.8s	remaining: 1.19s
# 499:	learn: 0.0506199	total: 5.99s	remaining: 0us
# 0:	learn: 0.2055215	total: 13.6ms	remaining: 6.76s
# 100:	learn: 0.0763075	total: 1.23s	remaining: 4.88s
# 200:	learn: 0.0685324	total: 2.43s	remaining: 3.62s
# 300:	learn: 0.0631661	total: 3.63s	remaining: 2.4s
# 400:	learn: 0.0583137	total: 4.82s	remaining: 1.19s
# 499:	learn: 0.0539443	total: 6.02s	remaining: 0us
# 0:	learn: 0.2371912	total: 16.7ms	remaining: 8.34s
# 100:	learn: 0.0700643	total: 1.39s	remaining: 5.51s
# 200:	learn: 0.0593808	total: 2.77s	remaining: 4.12s
# 300:	learn: 0.0511137	total: 4.13s	remaining: 2.73s
# 400:	learn: 0.0448119	total: 5.5s	remaining: 1.36s
# 499:	learn: 0.0402001	total: 6.84s	remaining: 0us
# 0:	learn: 0.2732204	total: 15.2ms	remaining: 7.6s
# 100:	learn: 0.0640918	total: 1.4s	remaining: 5.52s
# 200:	learn: 0.0534175	total: 2.78s	remaining: 4.14s
# 300:	learn: 0.0464209	total: 4.15s	remaining: 2.75s
# 400:	learn: 0.0408348	total: 5.52s	remaining: 1.36s
# 499:	learn: 0.0366167	total: 6.87s	remaining: 0us
# 0:	learn: 0.2139038	total: 15.4ms	remaining: 7.71s
# 100:	learn: 0.0677234	total: 1.39s	remaining: 5.49s
# 200:	learn: 0.0564966	total: 2.75s	remaining: 4.1s
# 300:	learn: 0.0492718	total: 4.14s	remaining: 2.74s
# 400:	learn: 0.0435115	total: 5.51s	remaining: 1.36s
# 499:	learn: 0.0384895	total: 6.88s	remaining: 0us
# 0:	learn: 0.3256655	total: 15.9ms	remaining: 7.91s
# 100:	learn: 0.0757980	total: 1.42s	remaining: 5.59s
# 200:	learn: 0.0660062	total: 2.78s	remaining: 4.13s
# 300:	learn: 0.0590057	total: 4.16s	remaining: 2.75s
# 400:	learn: 0.0537752	total: 5.53s	remaining: 1.36s
# 499:	learn: 0.0492670	total: 6.87s	remaining: 0us
# 0:	learn: 0.3657866	total: 16.1ms	remaining: 8.02s
# 100:	learn: 0.0694348	total: 1.4s	remaining: 5.54s
# 200:	learn: 0.0593979	total: 2.78s	remaining: 4.13s
# 300:	learn: 0.0534441	total: 4.13s	remaining: 2.73s
# 400:	learn: 0.0477534	total: 5.5s	remaining: 1.36s
# 499:	learn: 0.0439412	total: 6.84s	remaining: 0us
# 0:	learn: 0.3003119	total: 16.3ms	remaining: 8.12s
# 100:	learn: 0.0729378	total: 1.39s	remaining: 5.49s
# 200:	learn: 0.0638482	total: 2.75s	remaining: 4.09s
# 300:	learn: 0.0570525	total: 4.11s	remaining: 2.71s
# 400:	learn: 0.0519853	total: 5.5s	remaining: 1.36s
# 499:	learn: 0.0475215	total: 6.88s	remaining: 0us
# 0:	learn: 0.6679153	total: 13.4ms	remaining: 13.4s
# 100:	learn: 0.1273627	total: 1.21s	remaining: 10.8s
# 200:	learn: 0.1005370	total: 2.4s	remaining: 9.52s
# 300:	learn: 0.0941720	total: 3.57s	remaining: 8.3s
# 400:	learn: 0.0918317	total: 4.76s	remaining: 7.11s
# 500:	learn: 0.0905593	total: 5.95s	remaining: 5.92s
# 600:	learn: 0.0896299	total: 7.12s	remaining: 4.73s
# 700:	learn: 0.0888739	total: 8.31s	remaining: 3.54s
# 800:	learn: 0.0882694	total: 9.49s	remaining: 2.36s
# 900:	learn: 0.0876802	total: 10.7s	remaining: 1.17s
# 999:	learn: 0.0871259	total: 11.8s	remaining: 0us
# 0:	learn: 0.6718849	total: 12.6ms	remaining: 12.6s
# 100:	learn: 0.1198920	total: 1.18s	remaining: 10.5s
# 200:	learn: 0.0935938	total: 2.38s	remaining: 9.46s
# 300:	learn: 0.0879054	total: 3.58s	remaining: 8.31s
# 400:	learn: 0.0855389	total: 4.77s	remaining: 7.12s
# 500:	learn: 0.0841347	total: 5.95s	remaining: 5.92s
# 600:	learn: 0.0831291	total: 7.15s	remaining: 4.75s
# 700:	learn: 0.0824131	total: 8.34s	remaining: 3.56s
# 800:	learn: 0.0818282	total: 9.51s	remaining: 2.36s
# 900:	learn: 0.0812560	total: 10.7s	remaining: 1.17s
# 999:	learn: 0.0807361	total: 11.8s	remaining: 0us
# 0:	learn: 0.6640596	total: 12.4ms	remaining: 12.4s
# 100:	learn: 0.1187839	total: 1.19s	remaining: 10.6s
# 200:	learn: 0.0945654	total: 2.38s	remaining: 9.46s
# 300:	learn: 0.0892177	total: 3.58s	remaining: 8.3s
# 400:	learn: 0.0872437	total: 4.77s	remaining: 7.12s
# 500:	learn: 0.0860170	total: 5.97s	remaining: 5.95s
# 600:	learn: 0.0851965	total: 7.16s	remaining: 4.75s
# 700:	learn: 0.0845426	total: 8.36s	remaining: 3.57s
# 800:	learn: 0.0839959	total: 9.54s	remaining: 2.37s
# 900:	learn: 0.0834468	total: 10.7s	remaining: 1.18s
# 999:	learn: 0.0829429	total: 11.9s	remaining: 0us
# 0:	learn: 0.5918438	total: 16.4ms	remaining: 16.4s
# 100:	learn: 0.0885010	total: 1.39s	remaining: 12.4s
# 200:	learn: 0.0840359	total: 2.78s	remaining: 11.1s
# 300:	learn: 0.0807702	total: 4.16s	remaining: 9.66s
# 400:	learn: 0.0776283	total: 5.54s	remaining: 8.28s
# 500:	learn: 0.0750310	total: 6.92s	remaining: 6.9s
# 600:	learn: 0.0728777	total: 8.3s	remaining: 5.51s
# 700:	learn: 0.0706272	total: 9.66s	remaining: 4.12s
# 800:	learn: 0.0685551	total: 11.1s	remaining: 2.75s
# 900:	learn: 0.0668071	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0651043	total: 13.8s	remaining: 0us
# 0:	learn: 0.6081334	total: 14.8ms	remaining: 14.8s
# 100:	learn: 0.0824122	total: 1.4s	remaining: 12.5s
# 200:	learn: 0.0778945	total: 2.77s	remaining: 11s
# 300:	learn: 0.0746075	total: 4.14s	remaining: 9.63s
# 400:	learn: 0.0717102	total: 5.52s	remaining: 8.24s
# 500:	learn: 0.0689297	total: 6.9s	remaining: 6.87s
# 600:	learn: 0.0666323	total: 8.26s	remaining: 5.48s
# 700:	learn: 0.0646874	total: 9.6s	remaining: 4.09s
# 800:	learn: 0.0631370	total: 10.9s	remaining: 2.72s
# 900:	learn: 0.0615435	total: 12.3s	remaining: 1.35s
# 999:	learn: 0.0601307	total: 13.6s	remaining: 0us
# 0:	learn: 0.5814513	total: 14.8ms	remaining: 14.8s
# 100:	learn: 0.0847275	total: 1.4s	remaining: 12.4s
# 200:	learn: 0.0811075	total: 2.76s	remaining: 11s
# 300:	learn: 0.0781650	total: 4.13s	remaining: 9.59s
# 400:	learn: 0.0755196	total: 5.49s	remaining: 8.2s
# 500:	learn: 0.0730902	total: 6.83s	remaining: 6.8s
# 600:	learn: 0.0707804	total: 8.17s	remaining: 5.42s
# 700:	learn: 0.0690156	total: 9.51s	remaining: 4.06s
# 800:	learn: 0.0671376	total: 10.9s	remaining: 2.7s
# 900:	learn: 0.0654662	total: 12.2s	remaining: 1.34s
# 999:	learn: 0.0638208	total: 13.5s	remaining: 0us
# 0:	learn: 0.5240184	total: 15.5ms	remaining: 15.4s
# 100:	learn: 0.0852282	total: 1.39s	remaining: 12.4s
# 200:	learn: 0.0791233	total: 2.76s	remaining: 11s
# 300:	learn: 0.0746035	total: 4.12s	remaining: 9.58s
# 400:	learn: 0.0707451	total: 5.48s	remaining: 8.19s
# 500:	learn: 0.0672344	total: 6.84s	remaining: 6.82s
# 600:	learn: 0.0644093	total: 8.2s	remaining: 5.44s
# 700:	learn: 0.0617797	total: 9.57s	remaining: 4.08s
# 800:	learn: 0.0599147	total: 10.9s	remaining: 2.71s
# 900:	learn: 0.0575781	total: 12.3s	remaining: 1.35s
# 999:	learn: 0.0555650	total: 13.6s	remaining: 0us
# 0:	learn: 0.5495730	total: 16.6ms	remaining: 16.5s
# 100:	learn: 0.0787787	total: 1.41s	remaining: 12.6s
# 200:	learn: 0.0731848	total: 2.78s	remaining: 11.1s
# 300:	learn: 0.0679712	total: 4.17s	remaining: 9.68s
# 400:	learn: 0.0643798	total: 5.55s	remaining: 8.29s
# 500:	learn: 0.0615208	total: 6.92s	remaining: 6.89s
# 600:	learn: 0.0591971	total: 8.28s	remaining: 5.5s
# 700:	learn: 0.0570244	total: 9.64s	remaining: 4.11s
# 800:	learn: 0.0549241	total: 11s	remaining: 2.74s
# 900:	learn: 0.0526232	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0507300	total: 13.8s	remaining: 0us
# 0:	learn: 0.5077695	total: 15.5ms	remaining: 15.5s
# 100:	learn: 0.0815239	total: 1.4s	remaining: 12.4s
# 200:	learn: 0.0763605	total: 2.79s	remaining: 11.1s
# 300:	learn: 0.0722958	total: 4.18s	remaining: 9.7s
# 400:	learn: 0.0685550	total: 5.55s	remaining: 8.3s
# 500:	learn: 0.0652463	total: 6.92s	remaining: 6.89s
# 600:	learn: 0.0623850	total: 8.28s	remaining: 5.5s
# 700:	learn: 0.0597979	total: 9.65s	remaining: 4.12s
# 800:	learn: 0.0575497	total: 11s	remaining: 2.74s
# 900:	learn: 0.0556137	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0539556	total: 13.7s	remaining: 0us
# 0:	learn: 0.2914724	total: 16.6ms	remaining: 16.6s
# 100:	learn: 0.0739747	total: 1.4s	remaining: 12.5s
# 200:	learn: 0.0624355	total: 2.79s	remaining: 11.1s
# 300:	learn: 0.0549342	total: 4.17s	remaining: 9.68s
# 400:	learn: 0.0495676	total: 5.55s	remaining: 8.29s
# 500:	learn: 0.0451973	total: 6.92s	remaining: 6.9s
# 600:	learn: 0.0414324	total: 8.29s	remaining: 5.5s
# ...
# 200:	learn: 0.0607639	total: 2.82s	remaining: 11.2s
# 300:	learn: 0.0532356	total: 4.2s	remaining: 9.74s
# 400:	learn: 0.0470655	total: 5.54s	remaining: 8.28s
# 500:	learn: 0.0423587	total: 6.89s	remaining: 6.87s
# 600:	learn: 0.0388428	total: 8.24s	remaining: 5.47s
# 700:	learn: 0.0356690	total: 9.57s	remaining: 4.08s
# 800:	learn: 0.0332525	total: 10.9s	remaining: 2.72s
# 900:	learn: 0.0311214	total: 12.3s	remaining: 1.35s
# 999:	learn: 0.0290024	total: 13.6s	remaining: 0us
# 0:	learn: 0.3003894	total: 14.8ms	remaining: 14.8s
# 100:	learn: 0.0649957	total: 1.4s	remaining: 12.5s
# 200:	learn: 0.0548757	total: 2.75s	remaining: 10.9s
# 300:	learn: 0.0479560	total: 4.14s	remaining: 9.61s
# 400:	learn: 0.0420100	total: 5.54s	remaining: 8.27s
# 500:	learn: 0.0377587	total: 6.94s	remaining: 6.91s
# 600:	learn: 0.0338218	total: 8.32s	remaining: 5.52s
# 700:	learn: 0.0312597	total: 9.68s	remaining: 4.13s
# 800:	learn: 0.0290204	total: 11s	remaining: 2.74s
# 900:	learn: 0.0270019	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0252758	total: 13.7s	remaining: 0us
# 0:	learn: 0.2377778	total: 15.4ms	remaining: 15.4s
# 100:	learn: 0.0693063	total: 1.39s	remaining: 12.4s
# 200:	learn: 0.0590064	total: 2.76s	remaining: 11s
# 300:	learn: 0.0514773	total: 4.13s	remaining: 9.6s
# 400:	learn: 0.0456039	total: 5.51s	remaining: 8.24s
# 500:	learn: 0.0416753	total: 6.88s	remaining: 6.86s
# 600:	learn: 0.0383025	total: 8.26s	remaining: 5.48s
# 700:	learn: 0.0350846	total: 9.62s	remaining: 4.1s
# 800:	learn: 0.0323092	total: 11s	remaining: 2.73s
# 900:	learn: 0.0300892	total: 12.3s	remaining: 1.36s
# 999:	learn: 0.0281928	total: 13.7s	remaining: 0us
# 0:	learn: 0.2363782	total: 13.5ms	remaining: 13.5s
# 100:	learn: 0.0783339	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0703095	total: 2.38s	remaining: 9.47s
# 300:	learn: 0.0646287	total: 3.57s	remaining: 8.29s
# 400:	learn: 0.0598960	total: 4.76s	remaining: 7.11s
# 500:	learn: 0.0553737	total: 5.94s	remaining: 5.91s
# 600:	learn: 0.0517670	total: 7.1s	remaining: 4.71s
# 700:	learn: 0.0487589	total: 8.27s	remaining: 3.52s
# 800:	learn: 0.0462002	total: 9.44s	remaining: 2.35s
# 900:	learn: 0.0437112	total: 10.6s	remaining: 1.17s
# 999:	learn: 0.0416802	total: 11.8s	remaining: 0us
# 0:	learn: 0.2706061	total: 13.5ms	remaining: 13.4s
# 100:	learn: 0.0718709	total: 1.21s	remaining: 10.8s
# 200:	learn: 0.0639665	total: 2.42s	remaining: 9.62s
# 300:	learn: 0.0584950	total: 3.62s	remaining: 8.4s
# 400:	learn: 0.0547447	total: 4.81s	remaining: 7.19s
# 500:	learn: 0.0505961	total: 6s	remaining: 5.98s
# 600:	learn: 0.0471400	total: 7.17s	remaining: 4.76s
# 700:	learn: 0.0441681	total: 8.36s	remaining: 3.56s
# 800:	learn: 0.0416312	total: 9.54s	remaining: 2.37s
# 900:	learn: 0.0395791	total: 10.7s	remaining: 1.18s
# 999:	learn: 0.0377465	total: 11.9s	remaining: 0us
# 0:	learn: 0.2055215	total: 12.6ms	remaining: 12.6s
# 100:	learn: 0.0763075	total: 1.23s	remaining: 10.9s
# 200:	learn: 0.0685324	total: 2.4s	remaining: 9.56s
# 300:	learn: 0.0631661	total: 3.59s	remaining: 8.34s
# 400:	learn: 0.0583137	total: 4.78s	remaining: 7.15s
# 500:	learn: 0.0539130	total: 6s	remaining: 5.97s
# 600:	learn: 0.0505259	total: 7.17s	remaining: 4.76s
# 700:	learn: 0.0476644	total: 8.35s	remaining: 3.56s
# 800:	learn: 0.0450777	total: 9.52s	remaining: 2.37s
# 900:	learn: 0.0428481	total: 10.7s	remaining: 1.17s
# 999:	learn: 0.0408579	total: 11.9s	remaining: 0us
# 0:	learn: 0.2622916	total: 13ms	remaining: 6.5s
# 100:	learn: 0.0797995	total: 1.24s	remaining: 4.9s
# 200:	learn: 0.0726753	total: 2.55s	remaining: 3.8s
# 300:	learn: 0.0673441	total: 3.77s	remaining: 2.49s
# 400:	learn: 0.0626647	total: 4.95s	remaining: 1.22s
# 499:	learn: 0.0588746	total: 6.13s	remaining: 0us
# 0:	learn: 0.2986236	total: 13.6ms	remaining: 6.81s
# 100:	learn: 0.0736352	total: 1.21s	remaining: 4.78s
# 200:	learn: 0.0664192	total: 2.42s	remaining: 3.59s
# 300:	learn: 0.0610833	total: 3.6s	remaining: 2.38s
# 400:	learn: 0.0570850	total: 4.79s	remaining: 1.18s
# 499:	learn: 0.0538435	total: 5.96s	remaining: 0us
# 0:	learn: 0.2304999	total: 13.2ms	remaining: 6.56s
# 100:	learn: 0.0774727	total: 1.19s	remaining: 4.7s
# 200:	learn: 0.0709631	total: 2.36s	remaining: 3.51s
# 300:	learn: 0.0657038	total: 3.54s	remaining: 2.34s
# 400:	learn: 0.0612371	total: 4.76s	remaining: 1.17s
# 499:	learn: 0.0576786	total: 5.94s	remaining: 0us
# 0:	learn: 0.3645513	total: 14.3ms	remaining: 14.2s
# 100:	learn: 0.0828689	total: 1.22s	remaining: 10.9s
# 200:	learn: 0.0767768	total: 2.42s	remaining: 9.63s
# 300:	learn: 0.0727810	total: 3.63s	remaining: 8.44s
# 400:	learn: 0.0689219	total: 4.84s	remaining: 7.24s
# 500:	learn: 0.0655261	total: 6.05s	remaining: 6.03s
# 600:	learn: 0.0627362	total: 7.22s	remaining: 4.79s
# 700:	learn: 0.0604797	total: 8.39s	remaining: 3.58s
# 800:	learn: 0.0579746	total: 9.58s	remaining: 2.38s
# 900:	learn: 0.0557179	total: 10.8s	remaining: 1.18s
# 999:	learn: 0.0537190	total: 12s	remaining: 0us
# 0:	learn: 0.4013128	total: 13.9ms	remaining: 13.9s
# 100:	learn: 0.0771416	total: 1.21s	remaining: 10.8s
# 200:	learn: 0.0706426	total: 2.4s	remaining: 9.56s
# 300:	learn: 0.0666829	total: 3.6s	remaining: 8.35s
# 400:	learn: 0.0632167	total: 4.79s	remaining: 7.15s
# 500:	learn: 0.0600733	total: 5.98s	remaining: 5.95s
# 600:	learn: 0.0574418	total: 7.16s	remaining: 4.75s
# 700:	learn: 0.0550940	total: 8.32s	remaining: 3.55s
# 800:	learn: 0.0530014	total: 9.49s	remaining: 2.36s
# 900:	learn: 0.0512404	total: 10.6s	remaining: 1.17s
# 999:	learn: 0.0492676	total: 11.8s	remaining: 0us
# 0:	learn: 0.3299577	total: 13.9ms	remaining: 13.8s
# 100:	learn: 0.0799273	total: 1.2s	remaining: 10.7s
# 200:	learn: 0.0742707	total: 2.4s	remaining: 9.53s
# 300:	learn: 0.0702988	total: 3.59s	remaining: 8.35s
# 400:	learn: 0.0666054	total: 4.77s	remaining: 7.13s
# 500:	learn: 0.0632820	total: 5.97s	remaining: 5.95s
# 600:	learn: 0.0603874	total: 7.15s	remaining: 4.75s
# 700:	learn: 0.0579417	total: 8.33s	remaining: 3.55s
# 800:	learn: 0.0556989	total: 9.51s	remaining: 2.36s
# 900:	learn: 0.0534862	total: 10.7s	remaining: 1.17s
# 999:	learn: 0.0519110	total: 11.8s	remaining: 0us
# 0:	learn: 0.6675627	total: 15.2ms	remaining: 15.2s
# 100:	learn: 0.1165523	total: 1.41s	remaining: 12.6s
# 200:	learn: 0.0961528	total: 2.81s	remaining: 11.2s
# 300:	learn: 0.0913646	total: 4.19s	remaining: 9.74s
# 400:	learn: 0.0890184	total: 5.58s	remaining: 8.33s
# 500:	learn: 0.0874460	total: 6.96s	remaining: 6.93s
# 600:	learn: 0.0861982	total: 8.34s	remaining: 5.54s
# 700:	learn: 0.0852203	total: 9.72s	remaining: 4.14s
# 800:	learn: 0.0843231	total: 11.1s	remaining: 2.76s
# 900:	learn: 0.0834043	total: 12.5s	remaining: 1.37s
# 999:	learn: 0.0825269	total: 13.8s	remaining: 0us
# 0:	learn: 0.6719876	total: 15.5ms	remaining: 15.5s
# 100:	learn: 0.1112993	total: 1.41s	remaining: 12.5s
# 200:	learn: 0.0905840	total: 2.79s	remaining: 11.1s
# 300:	learn: 0.0851338	total: 4.18s	remaining: 9.71s
# 400:	learn: 0.0827521	total: 5.55s	remaining: 8.29s
# 500:	learn: 0.0811951	total: 6.93s	remaining: 6.91s
# 600:	learn: 0.0799721	total: 8.29s	remaining: 5.5s
# 700:	learn: 0.0790464	total: 9.64s	remaining: 4.11s
# 800:	learn: 0.0781506	total: 11s	remaining: 2.73s
# 900:	learn: 0.0773153	total: 12.3s	remaining: 1.36s
# 999:	learn: 0.0764949	total: 13.7s	remaining: 0us
# 0:	learn: 0.6646348	total: 17ms	remaining: 17s
# 100:	learn: 0.1096106	total: 1.41s	remaining: 12.6s
# 200:	learn: 0.0911161	total: 2.81s	remaining: 11.2s
# 300:	learn: 0.0869040	total: 4.19s	remaining: 9.73s
# 400:	learn: 0.0848501	total: 5.57s	remaining: 8.31s
# 500:	learn: 0.0835981	total: 6.94s	remaining: 6.91s
# 600:	learn: 0.0826262	total: 8.32s	remaining: 5.53s
# 700:	learn: 0.0817850	total: 9.68s	remaining: 4.13s
# 800:	learn: 0.0810138	total: 11.1s	remaining: 2.75s
# 900:	learn: 0.0802502	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0794980	total: 13.8s	remaining: 0us
# 0:	learn: 0.2914724	total: 14.7ms	remaining: 7.32s
# 100:	learn: 0.0739747	total: 1.4s	remaining: 5.53s
# 200:	learn: 0.0624355	total: 2.78s	remaining: 4.13s
# 300:	learn: 0.0549342	total: 4.16s	remaining: 2.75s
# 400:	learn: 0.0495676	total: 5.53s	remaining: 1.36s
# 499:	learn: 0.0452129	total: 6.88s	remaining: 0us
# 0:	learn: 0.3311333	total: 14.4ms	remaining: 7.19s
# 100:	learn: 0.0676433	total: 1.43s	remaining: 5.65s
# 200:	learn: 0.0577684	total: 2.83s	remaining: 4.21s
# 300:	learn: 0.0504244	total: 4.22s	remaining: 2.79s
# 400:	learn: 0.0448906	total: 5.6s	remaining: 1.38s
# 499:	learn: 0.0408375	total: 6.95s	remaining: 0us
# 0:	learn: 0.2663178	total: 15.4ms	remaining: 7.69s
# 100:	learn: 0.0709681	total: 1.4s	remaining: 5.54s
# 200:	learn: 0.0610026	total: 2.84s	remaining: 4.23s
# 300:	learn: 0.0542670	total: 4.28s	remaining: 2.83s
# 400:	learn: 0.0489611	total: 5.66s	remaining: 1.4s
# 499:	learn: 0.0448350	total: 7.03s	remaining: 0us
# 0:	learn: 0.6662190	total: 14.3ms	remaining: 14.3s
# 100:	learn: 0.1170029	total: 1.3s	remaining: 11.6s
# 200:	learn: 0.0970370	total: 2.6s	remaining: 10.3s
# 300:	learn: 0.0912919	total: 3.88s	remaining: 9.02s
# 400:	learn: 0.0887872	total: 5.19s	remaining: 7.76s
# 500:	learn: 0.0873881	total: 6.46s	remaining: 6.44s
# 600:	learn: 0.0865459	total: 7.72s	remaining: 5.13s
# 700:	learn: 0.0858309	total: 8.98s	remaining: 3.83s
# 800:	learn: 0.0852693	total: 10.2s	remaining: 2.54s
# 900:	learn: 0.0847693	total: 11.5s	remaining: 1.26s
# 999:	learn: 0.0842901	total: 12.7s	remaining: 0us
# 0:	learn: 0.6838230	total: 7.57ms	remaining: 371ms
# C:\Users\admin\PycharmProjects\venv\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 20 is smaller than n_iter=50. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# 49:	learn: 0.3804811	total: 320ms	remaining: 0us
# 0:	learn: 0.6838174	total: 7.36ms	remaining: 360ms
# 49:	learn: 0.3803155	total: 321ms	remaining: 0us
# 0:	learn: 0.6838186	total: 7.56ms	remaining: 371ms
# 49:	learn: 0.3805376	total: 317ms	remaining: 0us
# 0:	learn: 0.6544386	total: 7.87ms	remaining: 386ms
# 49:	learn: 0.1012971	total: 313ms	remaining: 0us
# 0:	learn: 0.6544167	total: 6.68ms	remaining: 327ms
# 49:	learn: 0.1001577	total: 318ms	remaining: 0us
# 0:	learn: 0.6544212	total: 6.7ms	remaining: 328ms
# 49:	learn: 0.1009626	total: 319ms	remaining: 0us
# 0:	learn: 0.6260416	total: 7.09ms	remaining: 347ms
# 49:	learn: 0.0567052	total: 320ms	remaining: 0us
# 0:	learn: 0.6260019	total: 7.11ms	remaining: 349ms
# 49:	learn: 0.0550707	total: 318ms	remaining: 0us
# 0:	learn: 0.6260100	total: 7.1ms	remaining: 348ms
# 49:	learn: 0.0551882	total: 315ms	remaining: 0us
# 0:	learn: 0.5986220	total: 7.23ms	remaining: 354ms
# 49:	learn: 0.0473956	total: 331ms	remaining: 0us
# 0:	learn: 0.5985658	total: 6.81ms	remaining: 334ms
# 49:	learn: 0.0456103	total: 321ms	remaining: 0us
# 0:	learn: 0.5985770	total: 7.07ms	remaining: 346ms
# 49:	learn: 0.0455693	total: 323ms	remaining: 0us
# 0:	learn: 0.5721672	total: 8.08ms	remaining: 396ms
# 49:	learn: 0.0439302	total: 326ms	remaining: 0us
# 0:	learn: 0.5720954	total: 7.38ms	remaining: 361ms
# 49:	learn: 0.0424225	total: 314ms	remaining: 0us
# 0:	learn: 0.5721110	total: 7.07ms	remaining: 347ms
# 49:	learn: 0.0423552	total: 319ms	remaining: 0us
# 0:	learn: 0.5466712	total: 7.45ms	remaining: 365ms
# 49:	learn: 0.0419439	total: 310ms	remaining: 0us
# 0:	learn: 0.5465823	total: 6.94ms	remaining: 340ms
# 49:	learn: 0.0405736	total: 322ms	remaining: 0us
# 0:	learn: 0.5466011	total: 7.04ms	remaining: 345ms
# 49:	learn: 0.0408975	total: 317ms	remaining: 0us
# 0:	learn: 0.5221168	total: 7.7ms	remaining: 377ms
# 49:	learn: 0.0405488	total: 322ms	remaining: 0us
# 0:	learn: 0.5220145	total: 7.62ms	remaining: 373ms
# 49:	learn: 0.0391948	total: 313ms	remaining: 0us
# 0:	learn: 0.5220358	total: 8.37ms	remaining: 410ms
# 49:	learn: 0.0395243	total: 318ms	remaining: 0us
# 0:	learn: 0.4984929	total: 7.5ms	remaining: 368ms
# 49:	learn: 0.0391340	total: 326ms	remaining: 0us
# 0:	learn: 0.4983751	total: 7.71ms	remaining: 378ms
# 49:	learn: 0.0383306	total: 313ms	remaining: 0us
# 0:	learn: 0.4983995	total: 7.5ms	remaining: 368ms
# 49:	learn: 0.0385017	total: 318ms	remaining: 0us
# 0:	learn: 0.4757862	total: 8.4ms	remaining: 412ms
# 49:	learn: 0.0381962	total: 310ms	remaining: 0us
# 0:	learn: 0.4756556	total: 8.06ms	remaining: 395ms
# 49:	learn: 0.0375630	total: 320ms	remaining: 0us
# 0:	learn: 0.4756813	total: 7.04ms	remaining: 345ms
# 49:	learn: 0.0375275	total: 315ms	remaining: 0us
# 0:	learn: 0.4539804	total: 7.55ms	remaining: 370ms
# 49:	learn: 0.0380353	total: 316ms	remaining: 0us
# 0:	learn: 0.4538363	total: 7.49ms	remaining: 367ms
# 49:	learn: 0.0365050	total: 323ms	remaining: 0us
# 0:	learn: 0.4538682	total: 6.89ms	remaining: 338ms
# 49:	learn: 0.0369291	total: 315ms	remaining: 0us
# 0:	learn: 0.6838448	total: 18.6ms	remaining: 913ms
# 49:	learn: 0.3808054	total: 814ms	remaining: 0us
# 0:	learn: 0.6838403	total: 18.9ms	remaining: 928ms
# 49:	learn: 0.3806179	total: 813ms	remaining: 0us
# 0:	learn: 0.6838409	total: 17.2ms	remaining: 844ms
# 49:	learn: 0.3809245	total: 809ms	remaining: 0us
# 0:	learn: 0.6545275	total: 18.3ms	remaining: 898ms
# 49:	learn: 0.1013914	total: 810ms	remaining: 0us
# 0:	learn: 0.6545045	total: 18.2ms	remaining: 890ms
# 49:	learn: 0.1002540	total: 824ms	remaining: 0us
# 0:	learn: 0.6545094	total: 18.8ms	remaining: 922ms
# 49:	learn: 0.1008223	total: 820ms	remaining: 0us
# 0:	learn: 0.6261920	total: 18.8ms	remaining: 922ms
# 49:	learn: 0.0556342	total: 818ms	remaining: 0us
# 0:	learn: 0.6261522	total: 17.5ms	remaining: 856ms
# 49:	learn: 0.0544056	total: 819ms	remaining: 0us
# 0:	learn: 0.6261603	total: 18ms	remaining: 883ms
# 49:	learn: 0.0546583	total: 818ms	remaining: 0us
# 0:	learn: 0.5988290	total: 18ms	remaining: 881ms
# 49:	learn: 0.0457286	total: 822ms	remaining: 0us
# 0:	learn: 0.5987731	total: 18.3ms	remaining: 896ms
# 49:	learn: 0.0443547	total: 818ms	remaining: 0us
# 0:	learn: 0.5987840	total: 18.3ms	remaining: 897ms
# 49:	learn: 0.0443953	total: 816ms	remaining: 0us
# 0:	learn: 0.5724284	total: 18.9ms	remaining: 926ms
# 49:	learn: 0.0421679	total: 818ms	remaining: 0us
# 0:	learn: 0.5723562	total: 17.6ms	remaining: 862ms
# 49:	learn: 0.0407914	total: 816ms	remaining: 0us
# 0:	learn: 0.5723720	total: 17.4ms	remaining: 851ms
# 49:	learn: 0.0405099	total: 816ms	remaining: 0us
# 0:	learn: 0.5469794	total: 18.4ms	remaining: 904ms
# 49:	learn: 0.0401793	total: 818ms	remaining: 0us
# 0:	learn: 0.5468926	total: 19.1ms	remaining: 938ms
# 49:	learn: 0.0389191	total: 824ms	remaining: 0us
# 0:	learn: 0.5469107	total: 19.3ms	remaining: 944ms
# 49:	learn: 0.0385556	total: 819ms	remaining: 0us
# 0:	learn: 0.5224697	total: 16.8ms	remaining: 822ms
# 49:	learn: 0.0383597	total: 820ms	remaining: 0us
# 0:	learn: 0.5223675	total: 19.4ms	remaining: 951ms
# 49:	learn: 0.0373840	total: 822ms	remaining: 0us
# 0:	learn: 0.5223900	total: 18.1ms	remaining: 889ms
# 49:	learn: 0.0372910	total: 808ms	remaining: 0us
# 0:	learn: 0.4988871	total: 17.3ms	remaining: 850ms
# 49:	learn: 0.0375436	total: 816ms	remaining: 0us
# 0:	learn: 0.4987703	total: 17ms	remaining: 832ms
# 49:	learn: 0.0359071	total: 818ms	remaining: 0us
# 0:	learn: 0.4987949	total: 16.9ms	remaining: 829ms
# 49:	learn: 0.0359005	total: 816ms	remaining: 0us
# 0:	learn: 0.4762160	total: 16.9ms	remaining: 830ms
# 49:	learn: 0.0357129	total: 822ms	remaining: 0us
# 0:	learn: 0.4760871	total: 17.9ms	remaining: 878ms
# 49:	learn: 0.0353928	total: 819ms	remaining: 0us
# 0:	learn: 0.4761142	total: 17.6ms	remaining: 865ms
# 49:	learn: 0.0348158	total: 850ms	remaining: 0us
# 0:	learn: 0.4544446	total: 18.3ms	remaining: 898ms
# 49:	learn: 0.0345211	total: 863ms	remaining: 0us
# 0:	learn: 0.4543020	total: 18.9ms	remaining: 927ms
# 49:	learn: 0.0334125	total: 867ms	remaining: 0us
# 0:	learn: 0.4543324	total: 16.6ms	remaining: 813ms
# 49:	learn: 0.0339086	total: 841ms	remaining: 0us
# 0:	learn: 0.5984739	total: 7.89ms	remaining: 386ms
# 49:	learn: 0.0465271	total: 354ms	remaining: 0us
# RandomizedSearchCV(cv=3,
#                    estimator=<catboost.core.CatBoostClassifier object at 0x000001E83BF04650>,
#                    n_iter=50,
#                    param_distributions={'depth': [8, 10], 'l2_leaf_reg': [1],
#                                         'learning_rate': array([0.01      , 0.04222222, 0.07444444, 0.10666667, 0.13888889,
#        0.17111111, 0.20333333, 0.23555556, 0.26777778, 0.3       ]),
#                                         'n_estimators': [50]},
#                    scoring='accuracy')

# %%
month_model_par = month_model.best_params_
month_model_par
# Out:
# {'n_estimators': 1000, 'learning_rate': 0.01, 'l2_leaf_reg': 7, 'depth': 4}

# %%
day_model_par = day_model.best_params_
day_model_par
# Out:
# {'n_estimators': 50,
#  'learning_rate': 0.10666666666666666,
#  'l2_leaf_reg': 1,
#  'depth': 8}

# %%
if X['wagnum'].dtype != 'int':
    X['wagnum'] = X['wagnum'].astype(int)

# Аналогично для 'ost_prob' и 'mean_run'
if X['ost_prob'].dtype != 'int':
    X['ost_prob'] = X['ost_prob'].astype(int)

if X['mean_run'].dtype != 'float':
    X['mean_run'] = X['mean_run'].astype(float)

# %%
param_dist_lgbm = {
    'num_leaves': [31, 61, 81],
    'learning_rate': [0.01, 0.05],
    'n_estimators': [50, 100],
    'max_depth': [7, 9]
}

# %%
param_dist_xgb = {
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 500],
    'subsample': [0.6, 0.7, 0.8, 0.9]
}

# %%
# Инициализация моделей
lgbm_model = LGBMClassifier()
xgb_model = XGBClassifier()

# Настройка RandomizedSearchCV
lgbm_model_month = RandomizedSearchCV(lgbm_model, param_distributions=param_dist_lgbm, n_iter=50, scoring='accuracy', cv=3)
lgbm_model_day = RandomizedSearchCV(lgbm_model, param_distributions=param_dist_lgbm, n_iter=50, scoring='accuracy', cv=3)

xgb_model_month = RandomizedSearchCV(xgb_model, param_distributions=param_dist_xgb, n_iter=50, scoring='accuracy', cv=3)
xgb_model_day = RandomizedSearchCV(xgb_model, param_distributions=param_dist_xgb, n_iter=50, scoring='accuracy', cv=3)

# %%
# Обучение моделей
lgbm_model_month.fit(X, y_month)
lgbm_model_day.fit(X, y_day)
# Out:
# C:\Users\admin\PycharmProjects\venv\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 24 is smaller than n_iter=50. Running 24 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\admin\PycharmProjects\venv\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 24 is smaller than n_iter=50. Running 24 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=LGBMClassifier(), n_iter=50,
#                    param_distributions={'learning_rate': [0.01, 0.05],
#                                         'max_depth': [7, 9],
#                                         'n_estimators': [50, 100],
#                                         'num_leaves': [31, 61, 81]},
#                    scoring='accuracy')

# %%
xgb_model_month.fit(X, y_month)
xgb_model_day.fit(X, y_day)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gpu_id=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            max_delta_step=None, max_depth=None,
#                                            max_leaves=None,
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=None, ...),
#                    n_iter=50,
#                    param_distributions={'learning_rate': [0.01, 0.05, 0.1, 0.2],
#                                         'max_depth': [3, 5, 7, 9],
#                                         'n_estimators': [50, 100, 200, 500],
#                                         'subsample': [0.6, 0.7, 0.8, 0.9]},
#                    scoring='accuracy')

# %% [markdown]
# ## генетический алгоритм для сборки моделей (день)

# %%
# Подготовка данных для предсказания
X_pred = X  # Ваши данные для предсказания

# Получение предсказаний от моделей
preds_gbm = lgbm_model_day.predict_proba(X_pred)[:, 1]
preds_xgb = xgb_model_day.predict_proba(X_pred)[:, 1]
preds_cbr = day_model.predict_proba(X_pred)[:, 1]

# %% [markdown]
# y_month, y_day

# %%
# Определение функции оценки
def evalEnsemble(weights):
    weight_gbm, weight_xgb = weights
    weight_cbr = 1.0 - weight_gbm - weight_xgb

    # Проверка на допустимость весов
    if weight_gbm < 0 or weight_xgb < 0 or weight_cbr < 0:
        return 0,  # Недопустимые веса получают наихудшую оценку

    ensemble_preds = weight_gbm * preds_gbm + weight_xgb * preds_xgb + weight_cbr * preds_cbr
    return f1_score(y_day, ensemble_preds.round()),  # Используйте ваши истинные метки y

# %%
# Настройка инструментов генетического алгоритма
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, 0, 1)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=2)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evalEnsemble)
toolbox.register("mate", tools.cxBlend, alpha=0.1)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.2, indpb=0.2)
toolbox.register("select", tools.selTournament, tournsize=3)

# Инициализация и запуск генетического алгоритма
population = toolbox.population(n=100)
ngen = 40
cxpb, mutpb = 0.5, 0.2

result, log = algorithms.eaSimple(population, toolbox, cxpb, mutpb, ngen, verbose=False)

# Лучший индивид
best_ind = tools.selBest(population, 1)[0]
print("Лучшие веса:", best_ind)
print("Лучшая F1-мера:", evalEnsemble(best_ind)[0])
# Out:
# C:\Users\admin\PycharmProjects\venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\admin\PycharmProjects\venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Лучшие веса: [0.0015203612139667796, 0.22593953978261294]
# Лучшая F1-мера: 0.32239657631954355

# %% [markdown]
# ## генетический алгоритм для сборки моделей (месяц)

# %%
# Подготовка данных для предсказания
X_pred = X  # Ваши данные для предсказания

# Получение предсказаний от моделей
preds_gbm = lgbm_model_month.predict_proba(X_pred)[:, 1]
preds_xgb = xgb_model_month.predict_proba(X_pred)[:, 1]
preds_cbr = month_model.predict_proba(X_pred)[:, 1]


# Определение функции оценки
def evalEnsemble(weights):
    weight_gbm, weight_xgb = weights
    weight_cbr = 1.0 - weight_gbm - weight_xgb

    # Проверка на допустимость весов
    if weight_gbm < 0 or weight_xgb < 0 or weight_cbr < 0:
        return 0,  # Недопустимые веса получают наихудшую оценку

    ensemble_preds = weight_gbm * preds_gbm + weight_xgb * preds_xgb + weight_cbr * preds_cbr
    return f1_score(y_month, ensemble_preds.round()),  # Используйте ваши истинные метки y

# Настройка инструментов генетического алгоритма
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, 0, 1)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=2)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evalEnsemble)
toolbox.register("mate", tools.cxBlend, alpha=0.1)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.2, indpb=0.2)
toolbox.register("select", tools.selTournament, tournsize=3)

# Инициализация и запуск генетического алгоритма
population = toolbox.population(n=100)
ngen = 40
cxpb, mutpb = 0.5, 0.2

result, log = algorithms.eaSimple(population, toolbox, cxpb, mutpb, ngen, verbose=False)

# Лучший индивид
best_ind1 = tools.selBest(population, 1)[0]
print("Лучшие веса:", best_ind1)
print("Лучшая F1-мера:", evalEnsemble(best_ind1)[0])
# Out:
# C:\Users\admin\PycharmProjects\venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\admin\PycharmProjects\venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Лучшие веса: [0.031397741767755886, 0.9212019055186602]
# Лучшая F1-мера: 0.6053827333100315

# %% [markdown]
# ### Тестирование

# %%
# Месяц на который будем предсказывать
#month_to_predict = pd.to_datetime('2023-02-01')
month_to_predict = pd.to_datetime('2023-03-01')

#Получаем целевой признак и фичи для предсказания
y_month_test, y_day_test, X_test = get_features(wag_prob, target, month_to_predict)

# %%
# Преобразование типов данных, если это необходимо
#  если 'wagnum' не int, преобразуйте его в int
if X_test['wagnum'].dtype != 'int':
    X_test['wagnum'] = X_test['wagnum'].astype(int)

# Аналогично для 'ost_prob' и 'mean_run'
if X_test['ost_prob'].dtype != 'int':
    X_test['ost_prob'] = X_test['ost_prob'].astype(int)

if X_test['mean_run'].dtype != 'float':
    X_test['mean_run'] = X_test['mean_run'].astype(float)

# %% [markdown]
# **месяц**

# %%
# Веса, найденные с помощью генетического алгоритма
weights = [0.3542673814180257, 0.11619747931788553]
weight_gbm, weight_xgb = weights
weight_cbr = 1.0 - weight_gbm - weight_xgb

# Получение предсказаний от моделей
preds_gbm = lgbm_model_month.predict_proba(X_test)[:, 1]
preds_xgb = xgb_model_month.predict_proba(X_test)[:, 1]
preds_cbr = month_model.predict_proba(X_test)[:, 1]

# Вычисление ансамблевых предсказаний
ensemble_preds = weight_gbm * preds_gbm + weight_xgb * preds_xgb + weight_cbr * preds_cbr

# Применение порога
threshold = 0.3#0.25  # Задайте подходящий порог
month_predictions = (ensemble_preds > threshold).astype(int)

# Оценка F1-меры
f1_month = f1_score(y_month_test, month_predictions)
print('F1 score day:', f1_month)
# Out:
# F1 score day: 0.10031842646602981

# %% [markdown]
# **подбор threshold месяц**

# %%
precision, recall, thresholds = precision_recall_curve(y_month_test, ensemble_preds)

# Выбор порога (например, максимальное гармоническое среднее)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
optimal_threshold1 = thresholds[ix]
optimal_threshold1
# Out:
# 0.03665146610946097

# %% [markdown]
# **день**

# %%
# Веса, найденные с помощью генетического алгоритма
weights = [0.12518670634065915, 0.1369754447367604]
weight_gbm, weight_xgb = weights
weight_cbr = 1.0 - weight_gbm - weight_xgb

# Получение предсказаний от моделей
preds_gbm = lgbm_model_day.predict_proba(X_test)[:, 1]
preds_xgb = xgb_model_day.predict_proba(X_test)[:, 1]
preds_cbr = day_model.predict_proba(X_test)[:, 1]

# Вычисление ансамблевых предсказаний
ensemble_preds = weight_gbm * preds_gbm + weight_xgb * preds_xgb + weight_cbr * preds_cbr

# Применение порога
threshold = 0.25  # Задайте подходящий порог
day_predictions = (ensemble_preds > threshold).astype(int)

# Оценка F1-меры
f1_day = f1_score(y_day_test, day_predictions)
print('F1 score day:', f1_day)
# Out:
# F1 score day: 0.031822959243255865

# %%
precision, recall, thresholds = precision_recall_curve(y_day_test, ensemble_preds)

# Выбор порога (например, максимальное гармоническое среднее)
fscore = (2 * precision * recall) / (precision + recall)
ix = np.argmax(fscore)
optimal_threshold = thresholds[ix]
optimal_threshold
# Out:
# 0.00272377908043896

# %%
# Делаем предсказания о ремонте вагонов на следующий месяц
#month_predictions = month_model.predict(X_test)
#day_predictions = day_model.predict(X_test)
# month_predictions = threshold_predict(month_model, X_test, 0.4)
# day_predictions = threshold_predict(day_model, X_test, 0.25)

# %%
# Считаем метрику по полученным предсказаниям

# Подсчетем метрику F1
f1_month = f1_score(y_month_test, month_predictions)
print('F1 score month:', f1_month)
f1_day = f1_score(y_day_test, day_predictions)
print('F1 score day:', f1_day)
# Out:
# F1 score month: 0.10031842646602981
# F1 score day: 0.031822959243255865

# %%
# Проверим соотношение отмеченных вагонов с фактическим значением
round(month_predictions.sum() / y_month_test.sum(), 2)
# Out:
# 0.05

# %%
# Проверим соотношение отмеченных вагонов с фактическим значением
round(day_predictions.sum() / y_day_test.sum(), 2)
# Out:
# 0.02

# %% [markdown]
# ### Создаем выходной файл и тестируем скорингом

# %%
# Создаем и записываем датасет с предсказаниями
pred_target = X_test[['wagnum']].copy()
pred_target['month'] = '2023-03-01'
pred_target['target_month'] = month_predictions
pred_target['target_day'] = day_predictions
# сохраним таргет за месяц  для выбранного периода отдельно
target_path = './prediction/target_predicton.csv'
pred_target.drop_duplicates(subset = 'wagnum').to_csv(target_path, index=False)

# Создаем и записываем датасет с истинными значениями
true_target = X_test[['wagnum']].copy()
true_target['target_month'] = y_month_test
true_target['target_day'] = y_day_test
true_target_path = './prediction/target_predicton_true.csv'
true_target.drop_duplicates(subset = 'wagnum').to_csv(true_target_path, index=False)

# %%
# оценим насколько хорошо удалось предсказать выбытие вагонов  по месяцу и по 10 дням
calc_f1_score( true_target_path, target_path)
# Out:
# 0.06607069285464284

# %% [markdown]
# 0.11344762837014791(max)

# %% [markdown]
# ## Заключение:
#
#
# ## Использованные Методы и Инструменты
#
# ### RandomizedSearchCV
# - **Цель:** Настройка гиперпараметров моделей.
# - **Модели:**
#   - `CatBoostClassifier`
#   - `LGBMClassifier`
#   - `XGBClassifier`
#
# ### Классификаторы
# - **CatBoostClassifier:** Оптимизирован для категориальных данных.
# - **LGBMClassifier:** Эффективен для больших наборов данных.
# - **XGBClassifier:** Высокая скорость и производительность.
#
# ### Генетический Алгоритм для Ансамблевых Моделей
# - **Функция `evalEnsemble`:** Возвращает F1-меру для взвешенной суммы предсказаний от трех классификаторов.
# - **Оптимизация весов:** Генетический алгоритм используется для определения оптимальных весов.
# - **Инструменты:** Использование библиотеки DEAP для настройки операций скрещивания, мутации и отбора.
#
# ## Результаты Генетического Алгоритма
# После 40 поколений, был найден оптимальный набор весов для комбинирования предсказаний моделей, с соответствующей F1-мерой на выборке заказчика.
#
# ---
#
# > *Команда [DS-60]*
